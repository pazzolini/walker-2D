# %%
import gymnasium as gym
from stable_baselines3 import SAC
import numpy as np
import os
from datetime import datetime

# %% [markdown]
# # Modifying the Environment using Action Wrappers
#
# **What are Actions?**
# - in the walker2D actions are torque values applied to the joints of the agent
# - define how strongly and in which direction the joints move
#
# **Which modifications did we implement?**
#
# **Action Scaler**
# - reduces the overall scale of the actions by 80% -> more controlled range
# - resulting in the agent learning more stable walking patterns and produce more natrual and controlled movements
#
# **SmoothActionWrapper**
# - smoothens actions by blending the current action with the previous one, avoiding jerking movements
#
# **ClippedActionWrappers**
# - ensures the actions remain with a moderate range, preventing extreme torque values
# - avoid actions that would destabilize the environment
#
# **JointScalerWrapper**
# - applies custom scaling factors for each joint to influce specific behaviors, such as limiting certain joints that contribute to jumping
# - finer control over specific joints

# %% [markdown]
# # Environment with 1M Timesteps

# %%
# Directories to save the model and logs
models_dir = "Models"
logdir = "logs_action"

# Create directories if they don't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

class ActionScaler(gym.ActionWrapper):
    def __init__(self, env, scale=0.5):
        super().__init__(env)
        self.scale = scale

    def action(self, action):
        return self.scale * action  # Scale down actions

class SmoothActionWrapper(gym.ActionWrapper):
    def __init__(self, env, alpha=0.9):
        super().__init__(env)
        self.prev_action = np.zeros(env.action_space.shape)
        self.alpha = alpha

    def action(self, action):
        smoothed_action = self.alpha * self.prev_action + (1 - self.alpha) * action
        self.prev_action = smoothed_action
        return smoothed_action

class ClippedActionWrapper(gym.ActionWrapper):
    def action(self, action):
        return np.clip(action, -0.5, 0.5)  # Limit actions within a moderate range

class JointScalerWrapper(gym.ActionWrapper):
    def __init__(self, env, scale_factors):
        super().__init__(env)
        self.scale_factors = scale_factors  # Scale for each joint

    def action(self, action):
        return action * self.scale_factors


seed=42

# Create the environment
try:
    base_env = gym.make('Walker2d-v5')
    env = ActionScaler(base_env, scale=0.8)  # Moderate scaling for overall actions
    env = SmoothActionWrapper(base_env, alpha=0.8)  # Smoothing actions
    env = ClippedActionWrapper(base_env)  # Clipping extreme actions
    env = JointScalerWrapper(base_env, scale_factors=np.array([1.0, 0.7, 0.7, 1.0, 1.0, 0.7]))  # Joint-specific scaling
    env.reset(seed=seed)
    print("Environment successfully created and reset.")
except Exception as e:
    print(f"Failed to create environment: {e}")
    env = None

# Initialize the SAC  model if not already initialized
model_path = f"{models_dir}/Sac_action.zip"

# Check if the model path exists
if os.path.exists(model_path) and env is not None:
    try:
        model = SAC.load(model_path, env=env)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Failed to load model: {e}")
        model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir)
else:
    print("Model path does not exist or environment creation failed. Initializing new model.")
    model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir,seed=seed)

## Training parameters
TIMESTEPS = 1000000  
total_timesteps = 1 * TIMESTEPS  # Total training steps after 30 iterations


if env is not None:
    # Train the model
    model.learn(total_timesteps=TIMESTEPS, tb_log_name="log_action")
    #Save the model after the full training
    model.save(f"{models_dir}/action_model")

    env.close()
else:
    print("Skipping training as the environment was not created successfully.")
# Out:
# Environment successfully created and reset.
# Model path does not exist or environment creation failed. Initializing new model.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs_action/log_action_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 3.83     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 3677     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 94       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 4.62     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 217      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 198      |
# | train/             |          |
# |    actor_loss      | -8.61    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.295   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 3.92     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 180      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 273      |
# | train/             |          |
# |    actor_loss      | -9.63    |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.95     |
# |    ent_coef_loss   | -0.521   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 172      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 6.56     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 160      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 415      |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.91     |
# |    ent_coef_loss   | -0.937   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 314      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | 5.87     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 131      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 546      |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.854    |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 445      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.8     |
# |    ep_rew_mean     | 6.83     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 85       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 738      |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.827    |
# |    ent_coef_loss   | -1.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 637      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.6     |
# |    ep_rew_mean     | 6.88     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 62       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1082     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.747    |
# |    ent_coef_loss   | -2.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 981      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.8     |
# |    ep_rew_mean     | 14.7     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 50       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 1816     |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.605    |
# |    ent_coef_loss   | -4.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1715     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.1     |
# |    ep_rew_mean     | 43.1     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 47       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 2741     |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 1.64     |
# |    ent_coef        | 0.466    |
# |    ent_coef_loss   | -6.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2640     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.3     |
# |    ep_rew_mean     | 68.3     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 49       |
# |    time_elapsed    | 70       |
# |    total_timesteps | 3454     |
# | train/             |          |
# |    actor_loss      | -43.2    |
# |    critic_loss     | 1.77     |
# |    ent_coef        | 0.382    |
# |    ent_coef_loss   | -7.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3353     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.8     |
# |    ep_rew_mean     | 89.2     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 50       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 4170     |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.312    |
# |    ent_coef_loss   | -9.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4069     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 51       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 4897     |
# | train/             |          |
# |    actor_loss      | -54.6    |
# |    critic_loss     | 3.29     |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4796     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 52       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 5654     |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 3.77     |
# |    ent_coef        | 0.206    |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5553     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 54       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 6534     |
# | train/             |          |
# |    actor_loss      | -64.1    |
# |    critic_loss     | 3.83     |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6433     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 56       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 7722     |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 5.56     |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -9.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7621     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 57       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 8514     |
# | train/             |          |
# |    actor_loss      | -75.5    |
# |    critic_loss     | 6.2      |
# |    ent_coef        | 0.0975   |
# |    ent_coef_loss   | -8.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8413     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 58       |
# |    time_elapsed    | 159      |
# |    total_timesteps | 9313     |
# | train/             |          |
# |    actor_loss      | -81.2    |
# |    critic_loss     | 6.69     |
# |    ent_coef        | 0.0804   |
# |    ent_coef_loss   | -8.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9212     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 59       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 10184    |
# | train/             |          |
# |    actor_loss      | -84.9    |
# |    critic_loss     | 7.41     |
# |    ent_coef        | 0.0666   |
# |    ent_coef_loss   | -6.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10083    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 60       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 10970    |
# | train/             |          |
# |    actor_loss      | -88.7    |
# |    critic_loss     | 9.89     |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10869    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 61       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 11725    |
# | train/             |          |
# |    actor_loss      | -88.1    |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11624    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 61       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 12636    |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | -1.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12535    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | 218      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 62       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 13523    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 7.87     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | 1.8      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13422    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | 226      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 63       |
# |    time_elapsed    | 226      |
# |    total_timesteps | 14342    |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | -0.909   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14241    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | 233      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 63       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 15095    |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | 0.92     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14994    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | 239      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 64       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 16007    |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 9.46     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | 0.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15906    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 64       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 16878    |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | 0.791    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16777    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 64       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 17594    |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17493    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 63       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 18249    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | -0.615   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18148    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 63       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 18889    |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18788    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 63       |
# |    time_elapsed    | 308      |
# |    total_timesteps | 19557    |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0453   |
# |    ent_coef_loss   | 1.96     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 316      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 63       |
# |    time_elapsed    | 319      |
# |    total_timesteps | 20213    |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 13       |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | 0.116    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20112    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 330      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 63       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 20872    |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | -0.133   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20771    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 339      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 63       |
# |    time_elapsed    | 340      |
# |    total_timesteps | 21488    |
# | train/             |          |
# |    actor_loss      | -124     |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | 0.462    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21387    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 341      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 62       |
# |    time_elapsed    | 353      |
# |    total_timesteps | 22234    |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | -0.511   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22133    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 345      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 62       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 23034    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 27.5     |
# |    ent_coef        | 0.0508   |
# |    ent_coef_loss   | 1.92     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22933    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 349      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 62       |
# |    time_elapsed    | 379      |
# |    total_timesteps | 23853    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 20.7     |
# |    ent_coef        | 0.0507   |
# |    ent_coef_loss   | 0.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23752    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 351      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 62       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 24578    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.0502   |
# |    ent_coef_loss   | -0.871   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24477    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 355      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 62       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 25320    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 19.4     |
# |    ent_coef        | 0.05     |
# |    ent_coef_loss   | 2.07     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 356      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 63       |
# |    time_elapsed    | 413      |
# |    total_timesteps | 26122    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 31.2     |
# |    ent_coef        | 0.0506   |
# |    ent_coef_loss   | -0.0659  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26021    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 355      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 63       |
# |    time_elapsed    | 427      |
# |    total_timesteps | 27084    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0517   |
# |    ent_coef_loss   | -1.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26983    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 358      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 63       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 27867    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 0.687    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27766    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 360      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 64       |
# |    time_elapsed    | 440      |
# |    total_timesteps | 28606    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.052    |
# |    ent_coef_loss   | -0.823   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28505    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 366      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 65       |
# |    time_elapsed    | 445      |
# |    total_timesteps | 29286    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.0534   |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29185    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 373      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 66       |
# |    time_elapsed    | 451      |
# |    total_timesteps | 30156    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | -0.861   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30055    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 375      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 67       |
# |    time_elapsed    | 456      |
# |    total_timesteps | 30897    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30796    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 374      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 68       |
# |    time_elapsed    | 460      |
# |    total_timesteps | 31612    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 32.1     |
# |    ent_coef        | 0.0548   |
# |    ent_coef_loss   | 0.955    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31511    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 374      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 69       |
# |    time_elapsed    | 466      |
# |    total_timesteps | 32468    |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 17.6     |
# |    ent_coef        | 0.0555   |
# |    ent_coef_loss   | -0.172   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32367    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 373      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 70       |
# |    time_elapsed    | 472      |
# |    total_timesteps | 33371    |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 30.2     |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | -0.0805  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33270    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 370      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 71       |
# |    time_elapsed    | 478      |
# |    total_timesteps | 34172    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34071    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 370      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 71       |
# |    time_elapsed    | 490      |
# |    total_timesteps | 35007    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.0563   |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34906    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 368      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 70       |
# |    time_elapsed    | 503      |
# |    total_timesteps | 35773    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0563   |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35672    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 367      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 70       |
# |    time_elapsed    | 517      |
# |    total_timesteps | 36573    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0526   |
# |    ent_coef_loss   | -0.402   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36472    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 375      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 71       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 37383    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37282    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 380      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 72       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 38243    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0539   |
# |    ent_coef_loss   | 0.364    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38142    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 378      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 73       |
# |    time_elapsed    | 531      |
# |    total_timesteps | 38948    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38847    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 380      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 74       |
# |    time_elapsed    | 536      |
# |    total_timesteps | 39739    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0515   |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39638    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 385      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 74       |
# |    time_elapsed    | 544      |
# |    total_timesteps | 40661    |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 20.4     |
# |    ent_coef        | 0.0502   |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40560    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 392      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 74       |
# |    time_elapsed    | 561      |
# |    total_timesteps | 41614    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 17.8     |
# |    ent_coef        | 0.0492   |
# |    ent_coef_loss   | 0.0259   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41513    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 397      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 73       |
# |    time_elapsed    | 580      |
# |    total_timesteps | 42619    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -0.657   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42518    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 398      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 72       |
# |    time_elapsed    | 601      |
# |    total_timesteps | 43566    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0516   |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43465    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 399      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 72       |
# |    time_elapsed    | 614      |
# |    total_timesteps | 44459    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0488   |
# |    ent_coef_loss   | -0.277   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 401      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 72       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 45330    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 18.2     |
# |    ent_coef        | 0.0488   |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45229    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 400      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 72       |
# |    time_elapsed    | 637      |
# |    total_timesteps | 46430    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | 0.523    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46329    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 401      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 73       |
# |    time_elapsed    | 644      |
# |    total_timesteps | 47498    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.0453   |
# |    ent_coef_loss   | 0.0698   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47397    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 406      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 75       |
# |    time_elapsed    | 655      |
# |    total_timesteps | 49251    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 0.0418   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49150    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 404      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 75       |
# |    time_elapsed    | 662      |
# |    total_timesteps | 50134    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.906   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50033    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 408      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 75       |
# |    time_elapsed    | 679      |
# |    total_timesteps | 51195    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 9.17     |
# |    ent_coef        | 0.0392   |
# |    ent_coef_loss   | 0.308    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51094    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 414      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 75       |
# |    time_elapsed    | 695      |
# |    total_timesteps | 52193    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.0385   |
# |    ent_coef_loss   | 0.356    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52092    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 402      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 74       |
# |    time_elapsed    | 705      |
# |    total_timesteps | 52875    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 13       |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52774    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 406      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 75       |
# |    time_elapsed    | 714      |
# |    total_timesteps | 53894    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | 1.89     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53793    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 408      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 76       |
# |    time_elapsed    | 720      |
# |    total_timesteps | 54846    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0379   |
# |    ent_coef_loss   | 1.95     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54745    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 409      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 76       |
# |    time_elapsed    | 727      |
# |    total_timesteps | 55714    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | -0.142   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55613    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 410      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 76       |
# |    time_elapsed    | 738      |
# |    total_timesteps | 56490    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0392   |
# |    ent_coef_loss   | -0.891   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56389    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 417      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 76       |
# |    time_elapsed    | 755      |
# |    total_timesteps | 57435    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | 1.89     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 421      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 75       |
# |    time_elapsed    | 769      |
# |    total_timesteps | 58374    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58273    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 432      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 75       |
# |    time_elapsed    | 787      |
# |    total_timesteps | 59557    |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 8.37     |
# |    ent_coef        | 0.0368   |
# |    ent_coef_loss   | 2.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 442      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 75       |
# |    time_elapsed    | 804      |
# |    total_timesteps | 60658    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60557    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 454      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 75       |
# |    time_elapsed    | 818      |
# |    total_timesteps | 62020    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 8.93     |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | -2.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61919    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 454      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 76       |
# |    time_elapsed    | 824      |
# |    total_timesteps | 62878    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.0377   |
# |    ent_coef_loss   | -1.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62777    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | 456      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 76       |
# |    time_elapsed    | 831      |
# |    total_timesteps | 63651    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | -0.275   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63550    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 456      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 76       |
# |    time_elapsed    | 848      |
# |    total_timesteps | 64581    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0377   |
# |    ent_coef_loss   | 0.482    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 453      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 75       |
# |    time_elapsed    | 863      |
# |    total_timesteps | 65490    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | 0.0823   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65389    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | 451      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 75       |
# |    time_elapsed    | 876      |
# |    total_timesteps | 66289    |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 8.71     |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | 0.232    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66188    |
# ---------------------------------
# ...
# |    fps             | 80       |
# |    time_elapsed    | 11071    |
# |    total_timesteps | 892196   |
# | train/             |          |
# |    actor_loss      | -354     |
# |    critic_loss     | 6.2      |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | 0.294    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 892095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 958      |
# |    ep_rew_mean     | 4.07e+03 |
# | time/              |          |
# |    episodes        | 1584     |
# |    fps             | 80       |
# |    time_elapsed    | 11106    |
# |    total_timesteps | 896196   |
# | train/             |          |
# |    actor_loss      | -360     |
# |    critic_loss     | 6.35     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | 0.755    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 896095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 958      |
# |    ep_rew_mean     | 4.08e+03 |
# | time/              |          |
# |    episodes        | 1588     |
# |    fps             | 80       |
# |    time_elapsed    | 11141    |
# |    total_timesteps | 900196   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 7.76     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 900095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 958      |
# |    ep_rew_mean     | 4.08e+03 |
# | time/              |          |
# |    episodes        | 1592     |
# |    fps             | 80       |
# |    time_elapsed    | 11176    |
# |    total_timesteps | 904196   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 5.56     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 904095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 948      |
# |    ep_rew_mean     | 4.04e+03 |
# | time/              |          |
# |    episodes        | 1596     |
# |    fps             | 80       |
# |    time_elapsed    | 11202    |
# |    total_timesteps | 907197   |
# | train/             |          |
# |    actor_loss      | -357     |
# |    critic_loss     | 5.42     |
# |    ent_coef        | 0.0434   |
# |    ent_coef_loss   | -0.879   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 907096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 948      |
# |    ep_rew_mean     | 4.04e+03 |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 80       |
# |    time_elapsed    | 11267    |
# |    total_timesteps | 911197   |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0446   |
# |    ent_coef_loss   | 0.499    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 911096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 956      |
# |    ep_rew_mean     | 4.08e+03 |
# | time/              |          |
# |    episodes        | 1604     |
# |    fps             | 80       |
# |    time_elapsed    | 11347    |
# |    total_timesteps | 915197   |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 6.41     |
# |    ent_coef        | 0.0454   |
# |    ent_coef_loss   | -0.884   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 915096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.07e+03 |
# | time/              |          |
# |    episodes        | 1608     |
# |    fps             | 80       |
# |    time_elapsed    | 11419    |
# |    total_timesteps | 918860   |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 3.92     |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 918759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.07e+03 |
# | time/              |          |
# |    episodes        | 1612     |
# |    fps             | 80       |
# |    time_elapsed    | 11504    |
# |    total_timesteps | 922860   |
# | train/             |          |
# |    actor_loss      | -359     |
# |    critic_loss     | 6.02     |
# |    ent_coef        | 0.0434   |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 922759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.07e+03 |
# | time/              |          |
# |    episodes        | 1616     |
# |    fps             | 79       |
# |    time_elapsed    | 11602    |
# |    total_timesteps | 926860   |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 5.08     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | -0.0256  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 926759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.07e+03 |
# | time/              |          |
# |    episodes        | 1620     |
# |    fps             | 79       |
# |    time_elapsed    | 11688    |
# |    total_timesteps | 930860   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 4.37     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | -0.295   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 930759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.08e+03 |
# | time/              |          |
# |    episodes        | 1624     |
# |    fps             | 79       |
# |    time_elapsed    | 11760    |
# |    total_timesteps | 934860   |
# | train/             |          |
# |    actor_loss      | -356     |
# |    critic_loss     | 5.74     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -0.00579 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 934759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.08e+03 |
# | time/              |          |
# |    episodes        | 1628     |
# |    fps             | 79       |
# |    time_elapsed    | 11833    |
# |    total_timesteps | 938860   |
# | train/             |          |
# |    actor_loss      | -357     |
# |    critic_loss     | 5.28     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -2.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 938759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.09e+03 |
# | time/              |          |
# |    episodes        | 1632     |
# |    fps             | 79       |
# |    time_elapsed    | 11908    |
# |    total_timesteps | 942860   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 2.98     |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | 0.323    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 942759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.09e+03 |
# | time/              |          |
# |    episodes        | 1636     |
# |    fps             | 79       |
# |    time_elapsed    | 11980    |
# |    total_timesteps | 946860   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 4.07     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | -0.613   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 946759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.09e+03 |
# | time/              |          |
# |    episodes        | 1640     |
# |    fps             | 78       |
# |    time_elapsed    | 12060    |
# |    total_timesteps | 950860   |
# | train/             |          |
# |    actor_loss      | -351     |
# |    critic_loss     | 5.34     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | -0.361   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 950759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.1e+03  |
# | time/              |          |
# |    episodes        | 1644     |
# |    fps             | 78       |
# |    time_elapsed    | 12150    |
# |    total_timesteps | 954860   |
# | train/             |          |
# |    actor_loss      | -359     |
# |    critic_loss     | 4.12     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | 0.382    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 954759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.1e+03  |
# | time/              |          |
# |    episodes        | 1648     |
# |    fps             | 78       |
# |    time_elapsed    | 12232    |
# |    total_timesteps | 958860   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 958759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.1e+03  |
# | time/              |          |
# |    episodes        | 1652     |
# |    fps             | 78       |
# |    time_elapsed    | 12311    |
# |    total_timesteps | 962860   |
# | train/             |          |
# |    actor_loss      | -352     |
# |    critic_loss     | 7.15     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 962759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 4.11e+03 |
# | time/              |          |
# |    episodes        | 1656     |
# |    fps             | 73       |
# |    time_elapsed    | 13159    |
# |    total_timesteps | 966860   |
# | train/             |          |
# |    actor_loss      | -368     |
# |    critic_loss     | 3.93     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.873   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 966759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 969      |
# |    ep_rew_mean     | 4.19e+03 |
# | time/              |          |
# |    episodes        | 1660     |
# |    fps             | 73       |
# |    time_elapsed    | 13244    |
# |    total_timesteps | 970860   |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 4.97     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -0.0286  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 970759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 978      |
# |    ep_rew_mean     | 4.23e+03 |
# | time/              |          |
# |    episodes        | 1664     |
# |    fps             | 73       |
# |    time_elapsed    | 13328    |
# |    total_timesteps | 974860   |
# | train/             |          |
# |    actor_loss      | -356     |
# |    critic_loss     | 7.29     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 974759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 978      |
# |    ep_rew_mean     | 4.24e+03 |
# | time/              |          |
# |    episodes        | 1668     |
# |    fps             | 72       |
# |    time_elapsed    | 13418    |
# |    total_timesteps | 978860   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 4.24     |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 1.46     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 978759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 978      |
# |    ep_rew_mean     | 4.24e+03 |
# | time/              |          |
# |    episodes        | 1672     |
# |    fps             | 72       |
# |    time_elapsed    | 13503    |
# |    total_timesteps | 982860   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 5.03     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 982759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 969      |
# |    ep_rew_mean     | 4.2e+03  |
# | time/              |          |
# |    episodes        | 1676     |
# |    fps             | 72       |
# |    time_elapsed    | 13555    |
# |    total_timesteps | 985120   |
# | train/             |          |
# |    actor_loss      | -365     |
# |    critic_loss     | 6.41     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.523    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 985019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 969      |
# |    ep_rew_mean     | 4.21e+03 |
# | time/              |          |
# |    episodes        | 1680     |
# |    fps             | 72       |
# |    time_elapsed    | 13641    |
# |    total_timesteps | 989120   |
# | train/             |          |
# |    actor_loss      | -359     |
# |    critic_loss     | 5.6      |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | 0.225    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 989019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 969      |
# |    ep_rew_mean     | 4.21e+03 |
# | time/              |          |
# |    episodes        | 1684     |
# |    fps             | 72       |
# |    time_elapsed    | 13726    |
# |    total_timesteps | 993120   |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | -0.586   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 969      |
# |    ep_rew_mean     | 4.21e+03 |
# | time/              |          |
# |    episodes        | 1688     |
# |    fps             | 72       |
# |    time_elapsed    | 13814    |
# |    total_timesteps | 997120   |
# | train/             |          |
# |    actor_loss      | -355     |
# |    critic_loss     | 7.5      |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 0.4      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997019   |
# ---------------------------------

# %%
#evaluate model created with action wrappers 
import numpy as np
import json
import gymnasium as gym
from datetime import datetime
import os
from stable_baselines3 import SAC
from typing import Optional, Type

def evaluate_walker_model(
    model_path: str,
    num_episodes: int = 30,
    seed: Optional[int] = None
) -> dict:
    """
    Evaluate a pre-trained Walker2d model focusing on distance achieved and velocity maintained.
    
    Args:
        model_path: Path to the saved model
        num_episodes: Number of evaluation episodes
        seed: Random seed for evaluation
    
    Returns:
        Dictionary containing evaluation metrics
    """
    # Create evaluation environment
    eval_env = gym.make('Walker2d-v5')
    if seed is not None:
        eval_env.reset(seed=seed)
    
    # Load the trained model
    model = SAC.load(model_path)
    
    # Initialize storage for episode data
    episode_data = []
    
    for ep in range(num_episodes):
        obs, _ = eval_env.reset()
        done = False
        ep_data = {
            'episode_length': 0,
            'velocities': [],
            'terminated': False,
            'truncated': False
        }
        
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = eval_env.step(action)
            done = terminated or truncated
            
            # Update episode data
            ep_data['episode_length'] += 1
            ep_data['velocities'].append(float(info.get('x_velocity', 0)))
            if done:  # Store final position when episode ends
                ep_data['final_position'] = float(info.get('x_position', 0))
            ep_data['terminated'] = terminated
            ep_data['truncated'] = truncated
        
        # Calculate episode statistics
        avg_velocity = np.mean(ep_data['velocities'])
        ep_stats = {
            'episode': ep + 1,
            'episode_length': ep_data['episode_length'],
            'distance': ep_data['final_position'],
            'avg_velocity': avg_velocity,
            'reached_max_steps': ep_data['truncated']
        }
        
        episode_data.append(ep_stats)
        print(f"Episode {ep + 1}: "
              f"Length = {ep_stats['episode_length']}, "
              f"Position = {ep_stats['distance']:.2f}, "  
              f"Avg Velocity = {ep_stats['avg_velocity']:.2f}, "
              f"{'Completed' if ep_stats['reached_max_steps'] else 'Terminated'}")
    
    # Calculate overall statistics
    completion_rate = sum(1 for ep in episode_data if ep['reached_max_steps']) / num_episodes
    avg_distance = np.mean([ep['distance'] for ep in episode_data])
    std_distance = np.std([ep['distance'] for ep in episode_data])
    avg_velocity = np.mean([ep['avg_velocity'] for ep in episode_data])
    std_velocity = np.std([ep['avg_velocity'] for ep in episode_data])
    
    # Compile results
    results = {
        'completion_rate': float(completion_rate),
        'average_position': float(avg_distance),
        'position_std': float(std_distance),
        'average_velocity': float(avg_velocity),
        'velocity_std': float(std_velocity),
        'num_episodes': num_episodes,
        'evaluation_seed': seed,
        'timestamp': datetime.now().strftime("%Y%m%d_%H%M%S"),
        'episode_details': episode_data
    }
    
    # Print summary
    print("\nEvaluation Results:")
    print(f"Completion Rate: {completion_rate*100:.1f}%")
    print(f"Average Position: {avg_distance:.2f} ± {std_distance:.2f}")
    print(f"Average Velocity: {avg_velocity:.2f} ± {std_velocity:.2f}")
    
    # Save results
    os.makedirs("evaluation_results", exist_ok=True)
    results_path = f"evaluation_results/eval_{results['timestamp']}.json"
    with open(results_path, 'w') as f:
        json.dump(results, f, indent=4)
    
    eval_env.close()
    return results

# %%
results = evaluate_walker_model(
    model_path="Models/action_model.zip",
    num_episodes=100,
    seed=42  
)
# Out:
# Episode 1: Length = 1000, Position = 26.07, Avg Velocity = 3.26, Completed
# Episode 2: Length = 1000, Position = 25.81, Avg Velocity = 3.23, Completed
# Episode 3: Length = 1000, Position = 25.64, Avg Velocity = 3.20, Completed
# Episode 4: Length = 1000, Position = 25.97, Avg Velocity = 3.25, Completed
# Episode 5: Length = 1000, Position = 26.47, Avg Velocity = 3.31, Completed
# Episode 6: Length = 1000, Position = 25.94, Avg Velocity = 3.24, Completed
# Episode 7: Length = 1000, Position = 25.01, Avg Velocity = 3.13, Completed
# Episode 8: Length = 1000, Position = 26.31, Avg Velocity = 3.29, Completed
# Episode 9: Length = 1000, Position = 26.67, Avg Velocity = 3.33, Completed
# Episode 10: Length = 1000, Position = 26.29, Avg Velocity = 3.29, Completed
# Episode 11: Length = 1000, Position = 25.95, Avg Velocity = 3.24, Completed
# Episode 12: Length = 1000, Position = 25.55, Avg Velocity = 3.19, Completed
# Episode 13: Length = 1000, Position = 26.43, Avg Velocity = 3.30, Completed
# Episode 14: Length = 1000, Position = 27.10, Avg Velocity = 3.39, Completed
# Episode 15: Length = 1000, Position = 26.32, Avg Velocity = 3.29, Completed
# Episode 16: Length = 1000, Position = 27.16, Avg Velocity = 3.40, Completed
# Episode 17: Length = 1000, Position = 25.21, Avg Velocity = 3.15, Completed
# Episode 18: Length = 1000, Position = 26.15, Avg Velocity = 3.27, Completed
# Episode 19: Length = 1000, Position = 26.48, Avg Velocity = 3.31, Completed
# Episode 20: Length = 1000, Position = 25.53, Avg Velocity = 3.19, Completed
# Episode 21: Length = 1000, Position = 27.14, Avg Velocity = 3.39, Completed
# Episode 22: Length = 1000, Position = 25.77, Avg Velocity = 3.22, Completed
# Episode 23: Length = 1000, Position = 26.51, Avg Velocity = 3.31, Completed
# Episode 24: Length = 1000, Position = 26.19, Avg Velocity = 3.27, Completed
# Episode 25: Length = 1000, Position = 26.35, Avg Velocity = 3.29, Completed
# Episode 26: Length = 1000, Position = 26.65, Avg Velocity = 3.33, Completed
# Episode 27: Length = 1000, Position = 25.40, Avg Velocity = 3.18, Completed
# Episode 28: Length = 1000, Position = 26.30, Avg Velocity = 3.29, Completed
# Episode 29: Length = 1000, Position = 25.95, Avg Velocity = 3.24, Completed
# Episode 30: Length = 1000, Position = 26.43, Avg Velocity = 3.30, Completed
# Episode 31: Length = 1000, Position = 25.77, Avg Velocity = 3.22, Completed
# Episode 32: Length = 1000, Position = 27.17, Avg Velocity = 3.40, Completed
# Episode 33: Length = 1000, Position = 26.46, Avg Velocity = 3.31, Completed
# Episode 34: Length = 1000, Position = 25.92, Avg Velocity = 3.24, Completed
# Episode 35: Length = 1000, Position = 25.94, Avg Velocity = 3.24, Completed
# Episode 36: Length = 1000, Position = 27.43, Avg Velocity = 3.43, Completed
# Episode 37: Length = 1000, Position = 25.86, Avg Velocity = 3.23, Completed
# Episode 38: Length = 1000, Position = 27.05, Avg Velocity = 3.38, Completed
# Episode 39: Length = 1000, Position = 27.08, Avg Velocity = 3.39, Completed
# Episode 40: Length = 1000, Position = 26.72, Avg Velocity = 3.34, Completed
# Episode 41: Length = 1000, Position = 26.25, Avg Velocity = 3.28, Completed
# Episode 42: Length = 1000, Position = 25.98, Avg Velocity = 3.25, Completed
# Episode 43: Length = 1000, Position = 26.19, Avg Velocity = 3.27, Completed
# Episode 44: Length = 1000, Position = 25.64, Avg Velocity = 3.20, Completed
# Episode 45: Length = 1000, Position = 26.15, Avg Velocity = 3.27, Completed
# Episode 46: Length = 1000, Position = 26.61, Avg Velocity = 3.33, Completed
# Episode 47: Length = 1000, Position = 26.62, Avg Velocity = 3.33, Completed
# Episode 48: Length = 1000, Position = 25.61, Avg Velocity = 3.20, Completed
# Episode 49: Length = 1000, Position = 25.35, Avg Velocity = 3.17, Completed
# Episode 50: Length = 1000, Position = 26.56, Avg Velocity = 3.32, Completed
# Episode 51: Length = 1000, Position = 25.74, Avg Velocity = 3.22, Completed
# Episode 52: Length = 1000, Position = 26.39, Avg Velocity = 3.30, Completed
# Episode 53: Length = 1000, Position = 25.85, Avg Velocity = 3.23, Completed
# Episode 54: Length = 1000, Position = 25.80, Avg Velocity = 3.23, Completed
# Episode 55: Length = 1000, Position = 26.12, Avg Velocity = 3.26, Completed
# Episode 56: Length = 1000, Position = 26.48, Avg Velocity = 3.31, Completed
# Episode 57: Length = 1000, Position = 26.41, Avg Velocity = 3.30, Completed
# Episode 58: Length = 1000, Position = 26.07, Avg Velocity = 3.26, Completed
# Episode 59: Length = 1000, Position = 25.53, Avg Velocity = 3.19, Completed
# Episode 60: Length = 1000, Position = 24.51, Avg Velocity = 3.06, Completed
# Episode 61: Length = 1000, Position = 24.75, Avg Velocity = 3.09, Completed
# Episode 62: Length = 1000, Position = 26.38, Avg Velocity = 3.30, Completed
# Episode 63: Length = 1000, Position = 26.51, Avg Velocity = 3.31, Completed
# Episode 64: Length = 1000, Position = 26.50, Avg Velocity = 3.31, Completed
# Episode 65: Length = 1000, Position = 25.73, Avg Velocity = 3.22, Completed
# Episode 66: Length = 1000, Position = 25.21, Avg Velocity = 3.15, Completed
# Episode 67: Length = 1000, Position = 27.07, Avg Velocity = 3.38, Completed
# Episode 68: Length = 1000, Position = 25.70, Avg Velocity = 3.21, Completed
# Episode 69: Length = 1000, Position = 27.14, Avg Velocity = 3.39, Completed
# Episode 70: Length = 1000, Position = 26.30, Avg Velocity = 3.29, Completed
# Episode 71: Length = 1000, Position = 25.41, Avg Velocity = 3.18, Completed
# Episode 72: Length = 1000, Position = 26.19, Avg Velocity = 3.27, Completed
# Episode 73: Length = 1000, Position = 27.35, Avg Velocity = 3.42, Completed
# Episode 74: Length = 1000, Position = 24.34, Avg Velocity = 3.04, Completed
# Episode 75: Length = 1000, Position = 24.94, Avg Velocity = 3.12, Completed
# Episode 76: Length = 1000, Position = 25.75, Avg Velocity = 3.22, Completed
# Episode 77: Length = 1000, Position = 25.01, Avg Velocity = 3.13, Completed
# Episode 78: Length = 1000, Position = 25.18, Avg Velocity = 3.15, Completed
# Episode 79: Length = 1000, Position = 26.95, Avg Velocity = 3.37, Completed
# Episode 80: Length = 1000, Position = 26.38, Avg Velocity = 3.30, Completed
# Episode 81: Length = 1000, Position = 26.53, Avg Velocity = 3.32, Completed
# Episode 82: Length = 1000, Position = 25.58, Avg Velocity = 3.20, Completed
# Episode 83: Length = 1000, Position = 26.15, Avg Velocity = 3.27, Completed
# Episode 84: Length = 1000, Position = 25.97, Avg Velocity = 3.25, Completed
# Episode 85: Length = 1000, Position = 25.74, Avg Velocity = 3.22, Completed
# Episode 86: Length = 1000, Position = 26.35, Avg Velocity = 3.29, Completed
# Episode 87: Length = 1000, Position = 25.21, Avg Velocity = 3.15, Completed
# Episode 88: Length = 1000, Position = 25.79, Avg Velocity = 3.22, Completed
# Episode 89: Length = 1000, Position = 25.69, Avg Velocity = 3.21, Completed
# Episode 90: Length = 1000, Position = 26.31, Avg Velocity = 3.29, Completed
# Episode 91: Length = 1000, Position = 26.03, Avg Velocity = 3.25, Completed
# Episode 92: Length = 1000, Position = 25.71, Avg Velocity = 3.21, Completed
# Episode 93: Length = 1000, Position = 26.04, Avg Velocity = 3.26, Completed
# Episode 94: Length = 1000, Position = 25.01, Avg Velocity = 3.13, Completed
# Episode 95: Length = 1000, Position = 25.61, Avg Velocity = 3.20, Completed
# Episode 96: Length = 1000, Position = 26.27, Avg Velocity = 3.28, Completed
# Episode 97: Length = 1000, Position = 25.30, Avg Velocity = 3.16, Completed
# Episode 98: Length = 1000, Position = 26.17, Avg Velocity = 3.27, Completed
# Episode 99: Length = 1000, Position = 25.21, Avg Velocity = 3.15, Completed
# Episode 100: Length = 1000, Position = 26.33, Avg Velocity = 3.29, Completed
#
# Evaluation Results:
# Completion Rate: 100.0%
# Average Position: 26.06 ± 0.62
# Average Velocity: 3.26 ± 0.08

# %%
import gymnasium as gym
from stable_baselines3 import SAC

# Load the environment with rendering enabled
env = gym.make('Walker2d-v5', render_mode="human") #With visualization
#env = gym.make('Walker2d-v5') #Without vizualization

# Path to the saved SAC model
model_path = "Models/action_model.zip" #  1 000 000 Timesteps



# Load the trained SAC model
model = SAC.load(model_path)

# Visualize for 30 episodes
for episode in range(30):
    obs, info = env.reset()
    done = False

    while not done:
        # Predict the action using the trained SAC model
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        

        # Check if the episode has ended
        done = terminated or truncated

    # Step through the environment
    
    print(f"Episode {episode}: Terminated={terminated}, Truncated={truncated}, Info={info}")

# Close the environment after visualization
env.close()
# Out:
# Episode 0: Terminated=False, Truncated=True, Info={'x_position': 26.441174970542075, 'z_distance_from_origin': 0.1382164139978035, 'x_velocity': 4.1956767005157936, 'reward_forward': 4.1956767005157936, 'reward_ctrl': -0.003815241098403931, 'reward_survive': 1.0}
# Episode 1: Terminated=False, Truncated=True, Info={'x_position': 26.7759192652565, 'z_distance_from_origin': -0.0223938805802395, 'x_velocity': 3.459583395450494, 'reward_forward': 3.459583395450494, 'reward_ctrl': -0.003067830562591553, 'reward_survive': 1.0}
# Episode 2: Terminated=False, Truncated=True, Info={'x_position': 26.29446161099367, 'z_distance_from_origin': -0.08377487355745483, 'x_velocity': 3.6419670137850524, 'reward_forward': 3.6419670137850524, 'reward_ctrl': -0.0033849701881408694, 'reward_survive': 1.0}
# Episode 3: Terminated=False, Truncated=True, Info={'x_position': 25.77429716545743, 'z_distance_from_origin': 0.06442728335947367, 'x_velocity': 3.778637527853679, 'reward_forward': 3.778637527853679, 'reward_ctrl': -0.002934083938598633, 'reward_survive': 1.0}
# Episode 4: Terminated=False, Truncated=True, Info={'x_position': 26.71630791459036, 'z_distance_from_origin': -0.08386806479277342, 'x_velocity': 2.335222064381526, 'reward_forward': 2.335222064381526, 'reward_ctrl': -0.003114370584487915, 'reward_survive': 1.0}
# Episode 5: Terminated=False, Truncated=True, Info={'x_position': 25.292356122191322, 'z_distance_from_origin': 0.2194598015202831, 'x_velocity': 4.23585616639377, 'reward_forward': 4.23585616639377, 'reward_ctrl': -0.0027017056941986083, 'reward_survive': 1.0}
# Episode 6: Terminated=False, Truncated=True, Info={'x_position': 25.150934042330167, 'z_distance_from_origin': 0.2591439117882819, 'x_velocity': 3.9887022785096704, 'reward_forward': 3.9887022785096704, 'reward_ctrl': -0.002870389223098755, 'reward_survive': 1.0}
# Episode 7: Terminated=False, Truncated=True, Info={'x_position': 26.31372822447443, 'z_distance_from_origin': 0.055271795146252245, 'x_velocity': 3.809596642536661, 'reward_forward': 3.809596642536661, 'reward_ctrl': -0.003123149871826172, 'reward_survive': 1.0}
# Episode 8: Terminated=False, Truncated=True, Info={'x_position': 25.867526455616726, 'z_distance_from_origin': 0.0005662147587042199, 'x_velocity': 3.87245612415299, 'reward_forward': 3.87245612415299, 'reward_ctrl': -0.0022841546535491944, 'reward_survive': 1.0}
# Episode 9: Terminated=False, Truncated=True, Info={'x_position': 24.510101899612625, 'z_distance_from_origin': 0.18364951071215052, 'x_velocity': 3.7123979682487374, 'reward_forward': 3.7123979682487374, 'reward_ctrl': -0.002534139156341553, 'reward_survive': 1.0}
# Episode 10: Terminated=False, Truncated=True, Info={'x_position': 24.84603730091667, 'z_distance_from_origin': 0.014374689297470322, 'x_velocity': 3.197721783938512, 'reward_forward': 3.197721783938512, 'reward_ctrl': -0.00317337965965271, 'reward_survive': 1.0}
# Episode 11: Terminated=False, Truncated=True, Info={'x_position': 26.523064355877413, 'z_distance_from_origin': 0.011044876416725025, 'x_velocity': 4.1672915242267905, 'reward_forward': 4.1672915242267905, 'reward_ctrl': -0.003951667070388794, 'reward_survive': 1.0}
# Episode 12: Terminated=False, Truncated=True, Info={'x_position': 24.792645643377732, 'z_distance_from_origin': 0.15108261887521368, 'x_velocity': 3.02526268636516, 'reward_forward': 3.02526268636516, 'reward_ctrl': -0.0027543015480041505, 'reward_survive': 1.0}
# Episode 13: Terminated=False, Truncated=True, Info={'x_position': 25.844766463872567, 'z_distance_from_origin': -0.04854828499090025, 'x_velocity': 4.22056405348048, 'reward_forward': 4.22056405348048, 'reward_ctrl': -0.0006566352248191834, 'reward_survive': 1.0}
# Episode 14: Terminated=False, Truncated=True, Info={'x_position': 26.931869189865832, 'z_distance_from_origin': -0.03983456684221465, 'x_velocity': 4.071712381466419, 'reward_forward': 4.071712381466419, 'reward_ctrl': -0.0029315361976623537, 'reward_survive': 1.0}
# Episode 15: Terminated=False, Truncated=True, Info={'x_position': 26.9490465576653, 'z_distance_from_origin': -0.041612167700131764, 'x_velocity': 3.0329070512857825, 'reward_forward': 3.0329070512857825, 'reward_ctrl': -0.003695615291595459, 'reward_survive': 1.0}
# Episode 16: Terminated=False, Truncated=True, Info={'x_position': 26.499238516973303, 'z_distance_from_origin': 0.050928326397516877, 'x_velocity': 4.843047396500655, 'reward_forward': 4.843047396500655, 'reward_ctrl': -0.004153376579284668, 'reward_survive': 1.0}
# Episode 17: Terminated=True, Truncated=False, Info={'x_position': 11.790634707594359, 'z_distance_from_origin': -0.45787612201938654, 'x_velocity': 3.437832590804213, 'reward_forward': 3.437832590804213, 'reward_ctrl': -0.005101747989654541, 'reward_survive': 0.0}
# Episode 18: Terminated=False, Truncated=True, Info={'x_position': 25.82920204470291, 'z_distance_from_origin': -0.07364919597919628, 'x_velocity': 3.5743132912879894, 'reward_forward': 3.5743132912879894, 'reward_ctrl': -0.002794819116592407, 'reward_survive': 1.0}
# Episode 19: Terminated=False, Truncated=True, Info={'x_position': 26.429605711993524, 'z_distance_from_origin': -0.04251814546740529, 'x_velocity': 3.2649799451109907, 'reward_forward': 3.2649799451109907, 'reward_ctrl': -0.004579570770263672, 'reward_survive': 1.0}
# Episode 20: Terminated=False, Truncated=True, Info={'x_position': 26.35041130170339, 'z_distance_from_origin': -0.08121446775766228, 'x_velocity': 3.100457013534008, 'reward_forward': 3.100457013534008, 'reward_ctrl': -0.002491389274597168, 'reward_survive': 1.0}
# Episode 21: Terminated=False, Truncated=True, Info={'x_position': 26.341327291200017, 'z_distance_from_origin': 0.10745522306452115, 'x_velocity': 3.7719419514887775, 'reward_forward': 3.7719419514887775, 'reward_ctrl': -0.003477598428726196, 'reward_survive': 1.0}
# Episode 22: Terminated=False, Truncated=True, Info={'x_position': 25.563402867424895, 'z_distance_from_origin': -0.0022645008827633095, 'x_velocity': 4.471764417562252, 'reward_forward': 4.471764417562252, 'reward_ctrl': -0.001657160997390747, 'reward_survive': 1.0}
# Episode 23: Terminated=False, Truncated=True, Info={'x_position': 25.8924319322085, 'z_distance_from_origin': -0.06591018037301999, 'x_velocity': 3.5149802821510256, 'reward_forward': 3.5149802821510256, 'reward_ctrl': -0.0024119625091552736, 'reward_survive': 1.0}
# Episode 24: Terminated=False, Truncated=True, Info={'x_position': 26.63953256432082, 'z_distance_from_origin': 0.0021652861947696334, 'x_velocity': 4.1581779180996925, 'reward_forward': 4.1581779180996925, 'reward_ctrl': -0.0035792393684387206, 'reward_survive': 1.0}
# Episode 25: Terminated=False, Truncated=True, Info={'x_position': 24.963256038543868, 'z_distance_from_origin': -0.02253999607173185, 'x_velocity': 3.444590918402657, 'reward_forward': 3.444590918402657, 'reward_ctrl': -0.002090817213058472, 'reward_survive': 1.0}
# Episode 26: Terminated=False, Truncated=True, Info={'x_position': 26.987035190756625, 'z_distance_from_origin': -0.08596587162704661, 'x_velocity': 3.8535623812538944, 'reward_forward': 3.8535623812538944, 'reward_ctrl': -0.0037104408740997316, 'reward_survive': 1.0}
# Episode 27: Terminated=False, Truncated=True, Info={'x_position': 25.13282851697085, 'z_distance_from_origin': -0.08515925393117652, 'x_velocity': 3.043096952459745, 'reward_forward': 3.043096952459745, 'reward_ctrl': -0.003481076240539551, 'reward_survive': 1.0}
# Episode 28: Terminated=True, Truncated=False, Info={'x_position': 17.485571085325542, 'z_distance_from_origin': -0.45080783512330613, 'x_velocity': 2.914025832209788, 'reward_forward': 2.914025832209788, 'reward_ctrl': -0.004843251228332519, 'reward_survive': 0.0}
# Episode 29: Terminated=False, Truncated=True, Info={'x_position': 26.60465814446509, 'z_distance_from_origin': 0.06856948023545839, 'x_velocity': 2.977718213059699, 'reward_forward': 2.977718213059699, 'reward_ctrl': -0.00397502064704895, 'reward_survive': 1.0}

# %% [markdown]
# # Timestep 5M

# %%
# Directories to save the model and logs
models_dir = "Models"
logdir = "logs_action"

# Create directories if they don't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

class ActionScaler(gym.ActionWrapper):
    def __init__(self, env, scale=0.5):
        super().__init__(env)
        self.scale = scale

    def action(self, action):
        return self.scale * action  # Scale down actions

class SmoothActionWrapper(gym.ActionWrapper):
    def __init__(self, env, alpha=0.9):
        super().__init__(env)
        self.prev_action = np.zeros(env.action_space.shape)
        self.alpha = alpha

    def action(self, action):
        smoothed_action = self.alpha * self.prev_action + (1 - self.alpha) * action
        self.prev_action = smoothed_action
        return smoothed_action

class ClippedActionWrapper(gym.ActionWrapper):
    def action(self, action):
        return np.clip(action, -0.5, 0.5)  # Limit actions within a moderate range

class JointScalerWrapper(gym.ActionWrapper):
    def __init__(self, env, scale_factors):
        super().__init__(env)
        self.scale_factors = scale_factors  # Scale for each joint

    def action(self, action):
        return action * self.scale_factors


seed=42

# Create the environment
try:
    base_env = gym.make('Walker2d-v5')
    env = ActionScaler(base_env, scale=0.8)  # Moderate scaling for overall actions
    env = SmoothActionWrapper(base_env, alpha=0.8)  # Smoothing actions
    env = ClippedActionWrapper(base_env)  # Clipping extreme actions
    env = JointScalerWrapper(base_env, scale_factors=np.array([1.0, 0.7, 0.7, 1.0, 1.0, 0.7]))  # Joint-specific scaling
    env.reset(seed=seed)
    print("Environment successfully created and reset.")
except Exception as e:
    print(f"Failed to create environment: {e}")
    env = None

# Initialize the SAC  model if not already initialized
model_path = f"{models_dir}/Sac_action.zip"

# Check if the model path exists
if os.path.exists(model_path) and env is not None:
    try:
        model = SAC.load(model_path, env=env)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Failed to load model: {e}")
        model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir)
else:
    print("Model path does not exist or environment creation failed. Initializing new model.")
    model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir,seed=seed)

## Training parameters
TIMESTEPS = 5000000  
total_timesteps = 1 * TIMESTEPS  # Total training steps after 30 iterations


if env is not None:
    # Train the model
    model.learn(total_timesteps=TIMESTEPS, tb_log_name="log_action")
    #Save the model after the full training
    model.save(f"{models_dir}/action_model")

    env.close()
else:
    print("Skipping training as the environment was not created successfully.")
# Out:
# Environment successfully created and reset.
# Model path does not exist or environment creation failed. Initializing new model.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs_action/log_action_lr_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 3.83     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4228     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 94       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 4.63     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 269      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 198      |
# | train/             |          |
# |    actor_loss      | -8.61    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | 3.92     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 209      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 277      |
# | train/             |          |
# |    actor_loss      | -9.38    |
# |    critic_loss     | 1.74     |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 176      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 5.53     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 153      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 414      |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.91     |
# |    ent_coef_loss   | -0.942   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 313      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | 4.91     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 144      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 520      |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.882    |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 419      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.7     |
# |    ep_rew_mean     | 5.56     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 137      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 665      |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.845    |
# |    ent_coef_loss   | -1.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 564      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 5.7      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 130      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 819      |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.73     |
# |    ent_coef        | 0.807    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 718      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.8     |
# |    ep_rew_mean     | 15.5     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 125      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1371     |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 1.57     |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | -3.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1270     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.4     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 122      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2174     |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | -5.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2073     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 82
#      77 total_timesteps = 1 * TIMESTEPS  # Total training steps after 30 iterations
#      80 if env is not None:
#      81     # Train the model
# ---> 82     model.learn(total_timesteps=TIMESTEPS, tb_log_name="log_action_lr")
#      83     #Save the model after the full training
#      84     model.save(f"{models_dir}/action_model_5M_lr")
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:249, in SAC.train(self, gradient_steps, batch_size)
#     247 next_actions, next_log_prob = self.actor.action_log_prob(replay_data.next_observations)
#     248 # Compute the next Q values: min over all critics targets
# --> 249 next_q_values = th.cat(self.critic_target(replay_data.next_observations, next_actions), dim=1)
#     250 next_q_values, _ = th.min(next_q_values, dim=1, keepdim=True)
#     251 # add entropy term
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:977, in ContinuousCritic.forward(self, obs, actions)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/stable_baselines3/common/policies.py:977, in <genexpr>(.0)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/modules/activation.py:133, in ReLU.forward(self, input)
#     132 def forward(self, input: Tensor) -> Tensor:
# --> 133     return F.relu(input, inplace=self.inplace)
#
# File ~/.pyenv/versions/3.10.0/envs/project2_env/lib/python3.10/site-packages/torch/nn/functional.py:1704, in relu(input, inplace)
#    1702     result = torch.relu_(input)
#    1703 else:
# -> 1704     result = torch.relu(input)
#    1705 return result
#
# KeyboardInterrupt:

# %%
results = evaluate_walker_model(
    model_path="Models/action_model_5M.zip",
    num_episodes=100,
    seed=42  
)
# Out:
# Episode 1: Length = 498, Position = 14.50, Avg Velocity = 3.64, Terminated
# Episode 2: Length = 383, Position = 11.10, Avg Velocity = 3.62, Terminated
# Episode 3: Length = 1000, Position = 30.76, Avg Velocity = 3.84, Completed
# Episode 4: Length = 992, Position = 29.46, Avg Velocity = 3.71, Terminated
# Episode 5: Length = 672, Position = 20.18, Avg Velocity = 3.76, Terminated
# Episode 6: Length = 597, Position = 18.10, Avg Velocity = 3.79, Terminated
# Episode 7: Length = 560, Position = 16.04, Avg Velocity = 3.58, Terminated
# Episode 8: Length = 640, Position = 19.89, Avg Velocity = 3.88, Terminated
# Episode 9: Length = 769, Position = 23.26, Avg Velocity = 3.78, Terminated
# Episode 10: Length = 396, Position = 12.22, Avg Velocity = 3.86, Terminated
# Episode 11: Length = 509, Position = 14.78, Avg Velocity = 3.63, Terminated
# Episode 12: Length = 1000, Position = 31.25, Avg Velocity = 3.91, Completed
# Episode 13: Length = 508, Position = 15.04, Avg Velocity = 3.70, Terminated
# Episode 14: Length = 532, Position = 16.05, Avg Velocity = 3.77, Terminated
# Episode 15: Length = 292, Position = 7.69, Avg Velocity = 3.29, Terminated
# Episode 16: Length = 991, Position = 29.97, Avg Velocity = 3.78, Terminated
# Episode 17: Length = 449, Position = 13.48, Avg Velocity = 3.75, Terminated
# Episode 18: Length = 426, Position = 12.82, Avg Velocity = 3.76, Terminated
# Episode 19: Length = 386, Position = 10.49, Avg Velocity = 3.40, Terminated
# Episode 20: Length = 1000, Position = 30.64, Avg Velocity = 3.83, Completed
# Episode 21: Length = 1000, Position = 30.66, Avg Velocity = 3.83, Completed
# Episode 22: Length = 739, Position = 23.63, Avg Velocity = 4.00, Terminated
# Episode 23: Length = 991, Position = 31.18, Avg Velocity = 3.93, Terminated
# Episode 24: Length = 511, Position = 14.14, Avg Velocity = 3.46, Terminated
# Episode 25: Length = 1000, Position = 31.30, Avg Velocity = 3.91, Completed
# Episode 26: Length = 1000, Position = 30.19, Avg Velocity = 3.77, Completed
# Episode 27: Length = 1000, Position = 31.00, Avg Velocity = 3.87, Completed
# Episode 28: Length = 631, Position = 18.72, Avg Velocity = 3.71, Terminated
# Episode 29: Length = 1000, Position = 30.83, Avg Velocity = 3.85, Completed
# Episode 30: Length = 402, Position = 12.37, Avg Velocity = 3.85, Terminated
# Episode 31: Length = 710, Position = 22.35, Avg Velocity = 3.94, Terminated
# Episode 32: Length = 1000, Position = 30.51, Avg Velocity = 3.81, Completed
# Episode 33: Length = 979, Position = 31.09, Avg Velocity = 3.97, Terminated
# Episode 34: Length = 604, Position = 18.49, Avg Velocity = 3.83, Terminated
# Episode 35: Length = 1000, Position = 31.11, Avg Velocity = 3.89, Completed
# Episode 36: Length = 804, Position = 25.14, Avg Velocity = 3.91, Terminated
# Episode 37: Length = 564, Position = 17.56, Avg Velocity = 3.89, Terminated
# Episode 38: Length = 478, Position = 13.95, Avg Velocity = 3.65, Terminated
# Episode 39: Length = 282, Position = 7.11, Avg Velocity = 3.15, Terminated
# Episode 40: Length = 979, Position = 30.96, Avg Velocity = 3.95, Terminated
# Episode 41: Length = 636, Position = 19.62, Avg Velocity = 3.86, Terminated
# Episode 42: Length = 553, Position = 16.03, Avg Velocity = 3.62, Terminated
# Episode 43: Length = 520, Position = 15.97, Avg Velocity = 3.84, Terminated
# Episode 44: Length = 995, Position = 30.82, Avg Velocity = 3.87, Terminated
# Episode 45: Length = 845, Position = 25.38, Avg Velocity = 3.76, Terminated
# Episode 46: Length = 749, Position = 22.85, Avg Velocity = 3.81, Terminated
# Episode 47: Length = 581, Position = 16.95, Avg Velocity = 3.65, Terminated
# Episode 48: Length = 1000, Position = 30.94, Avg Velocity = 3.87, Completed
# Episode 49: Length = 994, Position = 32.11, Avg Velocity = 4.04, Terminated
# Episode 50: Length = 705, Position = 21.06, Avg Velocity = 3.73, Terminated
# Episode 51: Length = 511, Position = 15.24, Avg Velocity = 3.73, Terminated
# Episode 52: Length = 532, Position = 16.45, Avg Velocity = 3.86, Terminated
# Episode 53: Length = 502, Position = 13.51, Avg Velocity = 3.36, Terminated
# Episode 54: Length = 551, Position = 16.74, Avg Velocity = 3.80, Terminated
# Episode 55: Length = 547, Position = 16.96, Avg Velocity = 3.88, Terminated
# Episode 56: Length = 702, Position = 21.19, Avg Velocity = 3.77, Terminated
# Episode 57: Length = 649, Position = 19.52, Avg Velocity = 3.76, Terminated
# Episode 58: Length = 1000, Position = 31.23, Avg Velocity = 3.90, Completed
# Episode 59: Length = 425, Position = 12.89, Avg Velocity = 3.79, Terminated
# Episode 60: Length = 1000, Position = 29.85, Avg Velocity = 3.73, Completed
# Episode 61: Length = 297, Position = 7.71, Avg Velocity = 3.24, Terminated
# Episode 62: Length = 888, Position = 28.23, Avg Velocity = 3.97, Terminated
# Episode 63: Length = 1000, Position = 29.97, Avg Velocity = 3.75, Completed
# Episode 64: Length = 607, Position = 18.99, Avg Velocity = 3.91, Terminated
# Episode 65: Length = 1000, Position = 31.97, Avg Velocity = 4.00, Completed
# Episode 66: Length = 672, Position = 20.17, Avg Velocity = 3.75, Terminated
# Episode 67: Length = 598, Position = 17.11, Avg Velocity = 3.58, Terminated
# Episode 68: Length = 905, Position = 28.32, Avg Velocity = 3.91, Terminated
# Episode 69: Length = 455, Position = 13.35, Avg Velocity = 3.67, Terminated
# Episode 70: Length = 527, Position = 16.41, Avg Velocity = 3.89, Terminated
# Episode 71: Length = 608, Position = 18.55, Avg Velocity = 3.81, Terminated
# Episode 72: Length = 1000, Position = 31.39, Avg Velocity = 3.92, Completed
# Episode 73: Length = 941, Position = 28.62, Avg Velocity = 3.80, Terminated
# Episode 74: Length = 435, Position = 12.69, Avg Velocity = 3.65, Terminated
# Episode 75: Length = 1000, Position = 30.46, Avg Velocity = 3.81, Completed
# Episode 76: Length = 670, Position = 19.16, Avg Velocity = 3.58, Terminated
# Episode 77: Length = 1000, Position = 28.86, Avg Velocity = 3.61, Completed
# Episode 78: Length = 403, Position = 12.03, Avg Velocity = 3.73, Terminated
# Episode 79: Length = 1000, Position = 29.90, Avg Velocity = 3.74, Completed
# Episode 80: Length = 1000, Position = 30.34, Avg Velocity = 3.79, Completed
# Episode 81: Length = 1000, Position = 28.06, Avg Velocity = 3.51, Completed
# Episode 82: Length = 1000, Position = 31.02, Avg Velocity = 3.88, Completed
# Episode 83: Length = 493, Position = 14.17, Avg Velocity = 3.59, Terminated
# Episode 84: Length = 495, Position = 14.79, Avg Velocity = 3.73, Terminated
# Episode 85: Length = 422, Position = 12.09, Avg Velocity = 3.58, Terminated
# Episode 86: Length = 1000, Position = 31.76, Avg Velocity = 3.97, Completed
# Episode 87: Length = 1000, Position = 31.62, Avg Velocity = 3.95, Completed
# Episode 88: Length = 530, Position = 15.19, Avg Velocity = 3.58, Terminated
# Episode 89: Length = 448, Position = 12.40, Avg Velocity = 3.46, Terminated
# Episode 90: Length = 1000, Position = 29.45, Avg Velocity = 3.68, Completed
# Episode 91: Length = 473, Position = 14.40, Avg Velocity = 3.81, Terminated
# Episode 92: Length = 516, Position = 15.48, Avg Velocity = 3.75, Terminated
# Episode 93: Length = 1000, Position = 29.53, Avg Velocity = 3.69, Completed
# Episode 94: Length = 963, Position = 30.90, Avg Velocity = 4.01, Terminated
# Episode 95: Length = 436, Position = 13.04, Avg Velocity = 3.74, Terminated
# Episode 96: Length = 814, Position = 25.02, Avg Velocity = 3.84, Terminated
# Episode 97: Length = 537, Position = 15.65, Avg Velocity = 3.64, Terminated
# Episode 98: Length = 504, Position = 15.28, Avg Velocity = 3.79, Terminated
# Episode 99: Length = 420, Position = 12.53, Avg Velocity = 3.73, Terminated
# Episode 100: Length = 440, Position = 13.32, Avg Velocity = 3.78, Terminated
#
# Evaluation Results:
# Completion Rate: 26.0%
# Average Position: 21.45 ± 7.65
# Average Velocity: 3.76 ± 0.16

# %%
import gymnasium as gym
from stable_baselines3 import SAC

# Load the environment with rendering enabled
env = gym.make('Walker2d-v5', render_mode="human") #With visualization
#env = gym.make('Walker2d-v5') #Without vizualization

# Path to the saved SAC model
model_path = "Models/action_model_5M.zip" #  1 000 000 Timesteps



# Load the trained SAC model
model = SAC.load(model_path)

# Visualize for 30 episodes
for episode in range(30):
    obs, info = env.reset()
    done = False

    while not done:
        # Predict the action using the trained SAC model
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        

        # Check if the episode has ended
        done = terminated or truncated

    # Step through the environment
    
    print(f"Episode {episode}: Terminated={terminated}, Truncated={truncated}, Info={info}")

# Close the environment after visualization
env.close()
# Out:
# Episode 0: Terminated=True, Truncated=False, Info={'x_position': 14.93922218576242, 'z_distance_from_origin': -0.45197897320272795, 'x_velocity': 0.09623708391548469, 'reward_forward': 0.09623708391548469, 'reward_ctrl': -0.004939473152160645, 'reward_survive': 0.0}
# Episode 1: Terminated=True, Truncated=False, Info={'x_position': 8.901989825340813, 'z_distance_from_origin': -0.4594776486849125, 'x_velocity': 1.6510976723393966, 'reward_forward': 1.6510976723393966, 'reward_ctrl': -0.005294286727905274, 'reward_survive': 0.0}
# Episode 2: Terminated=True, Truncated=False, Info={'x_position': 29.79922388337344, 'z_distance_from_origin': -0.459562865265813, 'x_velocity': 3.185406676682767, 'reward_forward': 3.185406676682767, 'reward_ctrl': -0.004816721916198731, 'reward_survive': 0.0}
# Episode 3: Terminated=True, Truncated=False, Info={'x_position': 11.455364692189283, 'z_distance_from_origin': -0.4588791871292496, 'x_velocity': 5.825166887738487, 'reward_forward': 5.825166887738487, 'reward_ctrl': -0.004853176593780518, 'reward_survive': 0.0}
# Episode 4: Terminated=True, Truncated=False, Info={'x_position': 24.36784800937699, 'z_distance_from_origin': -0.4715031151906228, 'x_velocity': 1.310553750271115, 'reward_forward': 1.310553750271115, 'reward_ctrl': -0.0033282253742218017, 'reward_survive': 0.0}
# Episode 5: Terminated=False, Truncated=True, Info={'x_position': 31.241445905545508, 'z_distance_from_origin': 0.06579802852672523, 'x_velocity': 4.237119934581202, 'reward_forward': 4.237119934581202, 'reward_ctrl': -0.0022640273571014405, 'reward_survive': 1.0}
# Episode 6: Terminated=True, Truncated=False, Info={'x_position': 23.462814245428216, 'z_distance_from_origin': -0.45787509631139733, 'x_velocity': 2.699250591708502, 'reward_forward': 2.699250591708502, 'reward_ctrl': -0.005631971836090088, 'reward_survive': 0.0}
# Episode 7: Terminated=True, Truncated=False, Info={'x_position': 29.10772213015043, 'z_distance_from_origin': -0.27287858079025606, 'x_velocity': 5.628839354588244, 'reward_forward': 5.628839354588244, 'reward_ctrl': -0.004944212913513183, 'reward_survive': 0.0}
# Episode 8: Terminated=True, Truncated=False, Info={'x_position': 9.865450383866671, 'z_distance_from_origin': -0.45544386049669905, 'x_velocity': 0.9279641062371891, 'reward_forward': 0.9279641062371891, 'reward_ctrl': -0.005614872455596924, 'reward_survive': 0.0}
# Episode 9: Terminated=True, Truncated=False, Info={'x_position': 12.090985158613677, 'z_distance_from_origin': -0.4617865407386462, 'x_velocity': 2.125785237558908, 'reward_forward': 2.125785237558908, 'reward_ctrl': -0.004530333518981934, 'reward_survive': 0.0}
# Episode 10: Terminated=True, Truncated=False, Info={'x_position': 12.388099073748565, 'z_distance_from_origin': -0.4680519977049622, 'x_velocity': 2.332730383107995, 'reward_forward': 2.332730383107995, 'reward_ctrl': -0.005995347023010254, 'reward_survive': 0.0}
# Episode 11: Terminated=False, Truncated=True, Info={'x_position': 30.651176679554613, 'z_distance_from_origin': 0.08260792441365217, 'x_velocity': 4.314132439051654, 'reward_forward': 4.314132439051654, 'reward_ctrl': -0.004080836772918701, 'reward_survive': 1.0}
# Episode 12: Terminated=True, Truncated=False, Info={'x_position': 13.91217226183695, 'z_distance_from_origin': -0.4748415625774737, 'x_velocity': 2.4397199967807204, 'reward_forward': 2.4397199967807204, 'reward_ctrl': -0.004145535945892334, 'reward_survive': 0.0}
# Episode 13: Terminated=False, Truncated=True, Info={'x_position': 31.581955816626735, 'z_distance_from_origin': 0.054905534546219936, 'x_velocity': 4.247183985965464, 'reward_forward': 4.247183985965464, 'reward_ctrl': -0.0033108789920806886, 'reward_survive': 1.0}
# Episode 14: Terminated=True, Truncated=False, Info={'x_position': 1.8772947608556017, 'z_distance_from_origin': -0.45750454641144966, 'x_velocity': 3.4291440518606495, 'reward_forward': 3.4291440518606495, 'reward_ctrl': -0.004347746849060059, 'reward_survive': 0.0}
# Episode 15: Terminated=False, Truncated=True, Info={'x_position': 31.448206558830694, 'z_distance_from_origin': -0.05542270433952634, 'x_velocity': 4.742605001199163, 'reward_forward': 4.742605001199163, 'reward_ctrl': -0.0033437085151672365, 'reward_survive': 1.0}
# Episode 16: Terminated=False, Truncated=True, Info={'x_position': 30.319365020496978, 'z_distance_from_origin': 0.006334133533961284, 'x_velocity': 3.480207932323953, 'reward_forward': 3.480207932323953, 'reward_ctrl': -0.0038716480731964113, 'reward_survive': 1.0}
# Episode 17: Terminated=True, Truncated=False, Info={'x_position': 14.69163451162587, 'z_distance_from_origin': -0.4929331321819981, 'x_velocity': 1.7037737342802117, 'reward_forward': 1.7037737342802117, 'reward_ctrl': -0.00480097484588623, 'reward_survive': 0.0}
# Episode 18: Terminated=True, Truncated=False, Info={'x_position': 4.3621746057744275, 'z_distance_from_origin': -0.2530121738071458, 'x_velocity': 6.431668385548428, 'reward_forward': 6.431668385548428, 'reward_ctrl': -0.00575209903717041, 'reward_survive': 0.0}
# Episode 19: Terminated=True, Truncated=False, Info={'x_position': 18.19607967546003, 'z_distance_from_origin': -0.49542677332088136, 'x_velocity': 1.8321087503325728, 'reward_forward': 1.8321087503325728, 'reward_ctrl': -0.005919609069824219, 'reward_survive': 0.0}
# Episode 20: Terminated=False, Truncated=True, Info={'x_position': 31.863220997331148, 'z_distance_from_origin': 0.05508115020252258, 'x_velocity': 4.514666575742066, 'reward_forward': 4.514666575742066, 'reward_ctrl': -0.0041883506774902345, 'reward_survive': 1.0}
# Episode 21: Terminated=True, Truncated=False, Info={'x_position': 22.249528683822515, 'z_distance_from_origin': -0.13094221228405534, 'x_velocity': 5.026882359844276, 'reward_forward': 5.026882359844276, 'reward_ctrl': -0.005167186260223389, 'reward_survive': 0.0}
# Episode 22: Terminated=True, Truncated=False, Info={'x_position': 9.336149429051552, 'z_distance_from_origin': -0.4671749868649624, 'x_velocity': 2.585620030160163, 'reward_forward': 2.585620030160163, 'reward_ctrl': -0.0048393974304199215, 'reward_survive': 0.0}
# Episode 23: Terminated=True, Truncated=False, Info={'x_position': 29.07273443349423, 'z_distance_from_origin': -0.4601375652808376, 'x_velocity': 1.885290357022562, 'reward_forward': 1.885290357022562, 'reward_ctrl': -0.004048734188079834, 'reward_survive': 0.0}
# Episode 24: Terminated=False, Truncated=True, Info={'x_position': 31.03982319728869, 'z_distance_from_origin': 0.06359421520851338, 'x_velocity': 4.182556528415482, 'reward_forward': 4.182556528415482, 'reward_ctrl': -0.0023489196300506593, 'reward_survive': 1.0}
# Episode 25: Terminated=False, Truncated=True, Info={'x_position': 30.687686914831826, 'z_distance_from_origin': 0.08271185773936485, 'x_velocity': 4.620216329074722, 'reward_forward': 4.620216329074722, 'reward_ctrl': -0.0036998865604400636, 'reward_survive': 1.0}
# Episode 26: Terminated=True, Truncated=False, Info={'x_position': 20.069782467434564, 'z_distance_from_origin': -0.4505424306565615, 'x_velocity': 1.5784847817683634, 'reward_forward': 1.5784847817683634, 'reward_ctrl': -0.0036972966194152835, 'reward_survive': 0.0}
# Episode 27: Terminated=False, Truncated=True, Info={'x_position': 29.271592346446013, 'z_distance_from_origin': -0.03844020517757318, 'x_velocity': 4.161864352491218, 'reward_forward': 4.161864352491218, 'reward_ctrl': -0.005037710189819336, 'reward_survive': 1.0}
# Episode 28: Terminated=True, Truncated=False, Info={'x_position': 13.9435233522253, 'z_distance_from_origin': -0.46022699081091656, 'x_velocity': 3.0956583878358757, 'reward_forward': 3.0956583878358757, 'reward_ctrl': -0.005193354606628418, 'reward_survive': 0.0}
# Episode 29: Terminated=True, Truncated=False, Info={'x_position': 11.404841659539844, 'z_distance_from_origin': -0.45578553620686, 'x_velocity': 6.088165794319922, 'reward_forward': 6.088165794319922, 'reward_ctrl': -0.004479663848876953, 'reward_survive': 0.0}

# %% [markdown]
# # Timestep 5M using Learning Rate

# %%
def linear_schedule(initial_value):
    """
    Linear learning rate schedule.
    :param initial_value: Initial learning rate (e.g., 3e-4).
    :return: A callable function that computes the current learning rate based on progress_remaining.
    """
    def schedule(progress_remaining):
        """
        Calculates the scaled learning rate.
        :param progress_remaining: Float between 1.0 (start of training) and 0.0 (end of training).
        :return: Current learning rate.
        """
        return progress_remaining * initial_value
    return schedule

# %%
# Directories to save the model and logs
models_dir = "Models"
logdir = "logs_action"

# Create directories if they don't exist
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

class ActionScaler(gym.ActionWrapper):
    def __init__(self, env, scale=0.5):
        super().__init__(env)
        self.scale = scale

    def action(self, action):
        return self.scale * action  # Scale down actions

class SmoothActionWrapper(gym.ActionWrapper):
    def __init__(self, env, alpha=0.9):
        super().__init__(env)
        self.prev_action = np.zeros(env.action_space.shape)
        self.alpha = alpha

    def action(self, action):
        smoothed_action = self.alpha * self.prev_action + (1 - self.alpha) * action
        self.prev_action = smoothed_action
        return smoothed_action

class ClippedActionWrapper(gym.ActionWrapper):
    def action(self, action):
        return np.clip(action, -0.5, 0.5)  # Limit actions within a moderate range

class JointScalerWrapper(gym.ActionWrapper):
    def __init__(self, env, scale_factors):
        super().__init__(env)
        self.scale_factors = scale_factors  # Scale for each joint

    def action(self, action):
        return action * self.scale_factors


seed=42

# Create the environment
try:
    base_env = gym.make('Walker2d-v5')
    env = ActionScaler(base_env, scale=0.8)  # Moderate scaling for overall actions
    env = SmoothActionWrapper(base_env, alpha=0.8)  # Smoothing actions
    env = ClippedActionWrapper(base_env)  # Clipping extreme actions
    env = JointScalerWrapper(base_env, scale_factors=np.array([1.0, 0.7, 0.7, 1.0, 1.0, 0.7]))  # Joint-specific scaling
    env.reset(seed=seed)
    print("Environment successfully created and reset.")
except Exception as e:
    print(f"Failed to create environment: {e}")
    env = None

# Initialize the SAC  model if not already initialized
model_path = f"{models_dir}/Sac_action.zip"

# Check if the model path exists
initial_lr = 3e-4 
if os.path.exists(model_path) and env is not None:
    try:
        model = SAC.load(model_path, env=env)
        print("Model loaded successfully.")
    except Exception as e:
        print(f"Failed to load model: {e}")
        model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir, learning_rate=linear_schedule(initial_lr))
else:
    print("Model path does not exist or environment creation failed. Initializing new model.")
    model = SAC('MlpPolicy', env, verbose=1, tensorboard_log=logdir,seed=seed,learning_rate=linear_schedule(initial_lr))

## Training parameters
TIMESTEPS = 5000000  
total_timesteps = 1 * TIMESTEPS  # Total training steps after 30 iterations


if env is not None:
    # Train the model
    model.learn(total_timesteps=TIMESTEPS, tb_log_name="log_action_lr")
    #Save the model after the full training
    model.save(f"{models_dir}/action_model_5M_lr")

    env.close()
else:
    print("Skipping training as the environment was not created successfully.")
# Out:
# Environment successfully created and reset.
# Model path does not exist or environment creation failed. Initializing new model.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs_action/log_action_lr_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 3.83     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4722     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 94       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 4.63     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 219      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 198      |
# | train/             |          |
# |    actor_loss      | -8.61    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | 3.92     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 170      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 277      |
# | train/             |          |
# |    actor_loss      | -9.38    |
# |    critic_loss     | 1.74     |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 176      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 5.53     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 147      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 414      |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.91     |
# |    ent_coef_loss   | -0.942   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 313      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | 4.91     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 140      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 520      |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.882    |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 419      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.7     |
# |    ep_rew_mean     | 5.56     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 138      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 665      |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.845    |
# |    ent_coef_loss   | -1.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 564      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 5.7      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 138      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 819      |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.73     |
# |    ent_coef        | 0.807    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 718      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.8     |
# |    ep_rew_mean     | 15.5     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 134      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1371     |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 1.57     |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | -3.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1270     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.4     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 133      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2174     |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | -5.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2073     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.7     |
# |    ep_rew_mean     | 34       |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 135      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 3388     |
# | train/             |          |
# |    actor_loss      | -37.5    |
# |    critic_loss     | 1.63     |
# |    ent_coef        | 0.389    |
# |    ent_coef_loss   | -7.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3287     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 54.3     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 136      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 4480     |
# | train/             |          |
# |    actor_loss      | -43      |
# |    critic_loss     | 1.75     |
# |    ent_coef        | 0.284    |
# |    ent_coef_loss   | -9.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4379     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 63       |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 138      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 5733     |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.198    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5632     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | 79.6     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 139      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 6656     |
# | train/             |          |
# |    actor_loss      | -50.1    |
# |    critic_loss     | 4.09     |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | -11.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6555     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | 84.8     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 139      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 7511     |
# | train/             |          |
# |    actor_loss      | -52.6    |
# |    critic_loss     | 4.06     |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -12      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7410     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 88.7     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 140      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 8340     |
# | train/             |          |
# |    actor_loss      | -54.5    |
# |    critic_loss     | 6.55     |
# |    ent_coef        | 0.0999   |
# |    ent_coef_loss   | -9.68    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 8239     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 92.1     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 141      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 8909     |
# | train/             |          |
# |    actor_loss      | -59.2    |
# |    critic_loss     | 6.25     |
# |    ent_coef        | 0.0872   |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 8808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 99.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 141      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 9590     |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 9.92     |
# |    ent_coef        | 0.0744   |
# |    ent_coef_loss   | -9.24    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 9489     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 141      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 10043    |
# | train/             |          |
# |    actor_loss      | -63.6    |
# |    critic_loss     | 9.29     |
# |    ent_coef        | 0.0682   |
# |    ent_coef_loss   | -8.73    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 9942     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 141      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 10595    |
# | train/             |          |
# |    actor_loss      | -64.1    |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | -4.49    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 10494    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 141      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 10985    |
# | train/             |          |
# |    actor_loss      | -68.7    |
# |    critic_loss     | 62.5     |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | -3.88    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 10884    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 141      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 11550    |
# | train/             |          |
# |    actor_loss      | -69.5    |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.0546   |
# |    ent_coef_loss   | -3.18    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 11449    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 142      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 13032    |
# | train/             |          |
# |    actor_loss      | -75.3    |
# |    critic_loss     | 9.88     |
# |    ent_coef        | 0.0497   |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 12931    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 142      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 13883    |
# | train/             |          |
# |    actor_loss      | -77.8    |
# |    critic_loss     | 24.3     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | 0.145    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 13782    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 143      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 14495    |
# | train/             |          |
# |    actor_loss      | -77.8    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | -0.616   |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 14394    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 144      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 15316    |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 27.7     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 15215    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 144      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 15963    |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | 0.65     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 15862    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 145      |
# |    time_elapsed    | 113      |
# |    total_timesteps | 16547    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 13       |
# |    ent_coef        | 0.0473   |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 16446    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 145      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 17096    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 18.6     |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 16995    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 145      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 17471    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | 1.84     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 17370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 145      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 17850    |
# | train/             |          |
# |    actor_loss      | -87.8    |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 1.45     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 17749    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 145      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 18313    |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | -0.754   |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 18212    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 145      |
# |    time_elapsed    | 129      |
# |    total_timesteps | 18778    |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 0.636    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 18677    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 145      |
# |    time_elapsed    | 132      |
# |    total_timesteps | 19258    |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 25.5     |
# |    ent_coef        | 0.0475   |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 19157    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 145      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 19726    |
# | train/             |          |
# |    actor_loss      | -91.8    |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0474   |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 19625    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 145      |
# |    time_elapsed    | 139      |
# |    total_timesteps | 20260    |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0481   |
# |    ent_coef_loss   | -0.359   |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 20159    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 145      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 20835    |
# | train/             |          |
# |    actor_loss      | -92.6    |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | 1.87     |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 20734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 145      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 21519    |
# | train/             |          |
# |    actor_loss      | -94      |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -0.69    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 21418    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | 211      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 145      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 22064    |
# | train/             |          |
# |    actor_loss      | -95.4    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0518   |
# |    ent_coef_loss   | 0.917    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 21963    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 217      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 145      |
# |    time_elapsed    | 155      |
# |    total_timesteps | 22674    |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0513   |
# |    ent_coef_loss   | -0.313   |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 22573    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 145      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 23314    |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 9.28     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 0.979    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 23213    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | 224      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 145      |
# |    time_elapsed    | 164      |
# |    total_timesteps | 24050    |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 23949    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 145      |
# |    time_elapsed    | 168      |
# |    total_timesteps | 24631    |
# | train/             |          |
# |    actor_loss      | -94.7    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | 0.282    |
# |    learning_rate   | 0.000299 |
# |    n_updates       | 24530    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 145      |
# |    time_elapsed    | 172      |
# |    total_timesteps | 25215    |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 25114    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 224      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 146      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 26085    |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 25984    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 146      |
# |    time_elapsed    | 183      |
# |    total_timesteps | 26746    |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 26645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 146      |
# |    time_elapsed    | 187      |
# |    total_timesteps | 27473    |
# | train/             |          |
# |    actor_loss      | -99      |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | -0.157   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 27372    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | 218      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 146      |
# |    time_elapsed    | 194      |
# |    total_timesteps | 28455    |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | 0.236    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 28354    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 146      |
# |    time_elapsed    | 201      |
# |    total_timesteps | 29549    |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 23.2     |
# |    ent_coef        | 0.0392   |
# |    ent_coef_loss   | 0.872    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 29448    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | 217      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 146      |
# |    time_elapsed    | 206      |
# |    total_timesteps | 30162    |
# | train/             |          |
# |    actor_loss      | -92.1    |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | 1.06     |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 30061    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 146      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 31259    |
# | train/             |          |
# |    actor_loss      | -91.3    |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.346    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 31158    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 146      |
# |    time_elapsed    | 220      |
# |    total_timesteps | 32360    |
# | train/             |          |
# |    actor_loss      | -95      |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 32259    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 146      |
# |    time_elapsed    | 225      |
# |    total_timesteps | 32980    |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 32879    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 166      |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 146      |
# |    time_elapsed    | 229      |
# |    total_timesteps | 33664    |
# | train/             |          |
# |    actor_loss      | -91.4    |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0395   |
# |    ent_coef_loss   | -0.682   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 33563    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 234      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 146      |
# |    time_elapsed    | 233      |
# |    total_timesteps | 34284    |
# | train/             |          |
# |    actor_loss      | -93.6    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 34183    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 146      |
# |    time_elapsed    | 238      |
# |    total_timesteps | 34974    |
# | train/             |          |
# |    actor_loss      | -94.3    |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.042    |
# |    ent_coef_loss   | 0.999    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 34873    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 145      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 35806    |
# | train/             |          |
# |    actor_loss      | -92.9    |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 0.727    |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 35705    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 144      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 36783    |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 9.68     |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | -0.126   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 36682    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | 263      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 144      |
# |    time_elapsed    | 259      |
# |    total_timesteps | 37575    |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.542   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 37474    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 145      |
# |    time_elapsed    | 268      |
# |    total_timesteps | 38988    |
# | train/             |          |
# |    actor_loss      | -97      |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | -0.692   |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 38887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 145      |
# |    time_elapsed    | 275      |
# |    total_timesteps | 40034    |
# | train/             |          |
# |    actor_loss      | -96.5    |
# |    critic_loss     | 9.31     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 2.53     |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 39933    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 145      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 41024    |
# | train/             |          |
# |    actor_loss      | -90.1    |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 40923    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 145      |
# |    time_elapsed    | 289      |
# |    total_timesteps | 42160    |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 9.42     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | -0.66    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 42059    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 300      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 145      |
# |    time_elapsed    | 297      |
# |    total_timesteps | 43273    |
# | train/             |          |
# |    actor_loss      | -94      |
# |    critic_loss     | 8.17     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | -0.839   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 43172    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 299      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 145      |
# |    time_elapsed    | 304      |
# |    total_timesteps | 44308    |
# | train/             |          |
# |    actor_loss      | -91.5    |
# |    critic_loss     | 8.08     |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | -0.672   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 44207    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 145      |
# |    time_elapsed    | 310      |
# |    total_timesteps | 45176    |
# | train/             |          |
# |    actor_loss      | -90.5    |
# |    critic_loss     | 8.54     |
# |    ent_coef        | 0.0375   |
# |    ent_coef_loss   | -0.61    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 45075    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 310      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 145      |
# |    time_elapsed    | 316      |
# |    total_timesteps | 46169    |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 7.07     |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 46068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 318      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 145      |
# |    time_elapsed    | 323      |
# |    total_timesteps | 47197    |
# | train/             |          |
# |    actor_loss      | -92.9    |
# |    critic_loss     | 12.8     |
# |    ent_coef        | 0.0379   |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 47096    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 324      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 145      |
# |    time_elapsed    | 330      |
# |    total_timesteps | 48140    |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.0368   |
# |    ent_coef_loss   | -0.985   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 48039    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 331      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 145      |
# |    time_elapsed    | 335      |
# |    total_timesteps | 48902    |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 7.26     |
# |    ent_coef        | 0.0374   |
# |    ent_coef_loss   | 0.91     |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 48801    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 341      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 145      |
# |    time_elapsed    | 339      |
# |    total_timesteps | 49609    |
# | train/             |          |
# |    actor_loss      | -97      |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0369   |
# |    ent_coef_loss   | 0.758    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 49508    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 350      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 146      |
# |    time_elapsed    | 346      |
# |    total_timesteps | 50522    |
# | train/             |          |
# |    actor_loss      | -95.3    |
# |    critic_loss     | 9.99     |
# |    ent_coef        | 0.0376   |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 50421    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 356      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 146      |
# |    time_elapsed    | 350      |
# |    total_timesteps | 51235    |
# | train/             |          |
# |    actor_loss      | -95.2    |
# |    critic_loss     | 9.17     |
# |    ent_coef        | 0.0377   |
# |    ent_coef_loss   | 0.917    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 51134    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 370      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 146      |
# |    time_elapsed    | 358      |
# |    total_timesteps | 52435    |
# | train/             |          |
# |    actor_loss      | -90.8    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0379   |
# |    ent_coef_loss   | -0.0214  |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 52334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 378      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 146      |
# |    time_elapsed    | 364      |
# |    total_timesteps | 53317    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 7.41     |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | -0.467   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 53216    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 383      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 146      |
# |    time_elapsed    | 371      |
# |    total_timesteps | 54253    |
# | train/             |          |
# |    actor_loss      | -97.2    |
# |    critic_loss     | 8.75     |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | -2.14    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 54152    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 388      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 146      |
# |    time_elapsed    | 377      |
# |    total_timesteps | 55140    |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | -0.628   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 55039    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 394      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 146      |
# |    time_elapsed    | 382      |
# |    total_timesteps | 55969    |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 8.8      |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | -0.407   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 55868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 397      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 146      |
# |    time_elapsed    | 387      |
# |    total_timesteps | 56691    |
# | train/             |          |
# |    actor_loss      | -97.8    |
# |    critic_loss     | 8.65     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 0.324    |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 56590    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 406      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 146      |
# |    time_elapsed    | 393      |
# |    total_timesteps | 57564    |
# | train/             |          |
# |    actor_loss      | -97.3    |
# |    critic_loss     | 8.25     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | 0.55     |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 57463    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 409      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 146      |
# |    time_elapsed    | 398      |
# |    total_timesteps | 58294    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 8.87     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | -0.583   |
# |    learning_rate   | 0.000297 |
# |    n_updates       | 58193    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 412      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 146      |
# |    time_elapsed    | 404      |
# |    total_timesteps | 59161    |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 9.56     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 0.515    |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 59060    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 411      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 146      |
# |    time_elapsed    | 409      |
# |    total_timesteps | 59981    |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 0.122    |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 59880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 408      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 146      |
# |    time_elapsed    | 414      |
# |    total_timesteps | 60679    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 9.83     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 60578    |
# ---------------------------------
# ...
# |    fps             | 120      |
# |    time_elapsed    | 40592    |
# |    total_timesteps | 4891464  |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 6.13     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.787   |
# |    learning_rate   | 6.51e-06 |
# |    n_updates       | 4891363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.06e+03 |
# | time/              |          |
# |    episodes        | 5720     |
# |    fps             | 120      |
# |    time_elapsed    | 40623    |
# |    total_timesteps | 4895464  |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 1.32     |
# |    ent_coef        | 0.0575   |
# |    ent_coef_loss   | -0.412   |
# |    learning_rate   | 6.27e-06 |
# |    n_updates       | 4895363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.06e+03 |
# | time/              |          |
# |    episodes        | 5724     |
# |    fps             | 120      |
# |    time_elapsed    | 40655    |
# |    total_timesteps | 4899464  |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 0.642    |
# |    ent_coef        | 0.0575   |
# |    ent_coef_loss   | 0.855    |
# |    learning_rate   | 6.03e-06 |
# |    n_updates       | 4899363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.06e+03 |
# | time/              |          |
# |    episodes        | 5728     |
# |    fps             | 120      |
# |    time_elapsed    | 40686    |
# |    total_timesteps | 4903464  |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.517   |
# |    learning_rate   | 5.79e-06 |
# |    n_updates       | 4903363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.06e+03 |
# | time/              |          |
# |    episodes        | 5732     |
# |    fps             | 120      |
# |    time_elapsed    | 40718    |
# |    total_timesteps | 4907464  |
# | train/             |          |
# |    actor_loss      | -471     |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0578   |
# |    ent_coef_loss   | -0.56    |
# |    learning_rate   | 5.55e-06 |
# |    n_updates       | 4907363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5736     |
# |    fps             | 120      |
# |    time_elapsed    | 40749    |
# |    total_timesteps | 4911464  |
# | train/             |          |
# |    actor_loss      | -470     |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.0578   |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 5.31e-06 |
# |    n_updates       | 4911363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5740     |
# |    fps             | 120      |
# |    time_elapsed    | 40781    |
# |    total_timesteps | 4915464  |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 1.09     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | 0.264    |
# |    learning_rate   | 5.07e-06 |
# |    n_updates       | 4915363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5744     |
# |    fps             | 120      |
# |    time_elapsed    | 40812    |
# |    total_timesteps | 4919464  |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 3.42     |
# |    ent_coef        | 0.0581   |
# |    ent_coef_loss   | 0.522    |
# |    learning_rate   | 4.83e-06 |
# |    n_updates       | 4919363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5748     |
# |    fps             | 120      |
# |    time_elapsed    | 40843    |
# |    total_timesteps | 4923464  |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 0.768    |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | 0.344    |
# |    learning_rate   | 4.59e-06 |
# |    n_updates       | 4923363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5752     |
# |    fps             | 120      |
# |    time_elapsed    | 40875    |
# |    total_timesteps | 4927464  |
# | train/             |          |
# |    actor_loss      | -477     |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 4.35e-06 |
# |    n_updates       | 4927363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5756     |
# |    fps             | 120      |
# |    time_elapsed    | 40906    |
# |    total_timesteps | 4931464  |
# | train/             |          |
# |    actor_loss      | -475     |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | 0.738    |
# |    learning_rate   | 4.11e-06 |
# |    n_updates       | 4931363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5760     |
# |    fps             | 120      |
# |    time_elapsed    | 40938    |
# |    total_timesteps | 4935464  |
# | train/             |          |
# |    actor_loss      | -472     |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 3.87e-06 |
# |    n_updates       | 4935363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5764     |
# |    fps             | 120      |
# |    time_elapsed    | 40969    |
# |    total_timesteps | 4939464  |
# | train/             |          |
# |    actor_loss      | -477     |
# |    critic_loss     | 0.924    |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 3.63e-06 |
# |    n_updates       | 4939363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5768     |
# |    fps             | 120      |
# |    time_elapsed    | 41000    |
# |    total_timesteps | 4943464  |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 0.877    |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 3.39e-06 |
# |    n_updates       | 4943363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5772     |
# |    fps             | 120      |
# |    time_elapsed    | 41032    |
# |    total_timesteps | 4947464  |
# | train/             |          |
# |    actor_loss      | -471     |
# |    critic_loss     | 0.804    |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | -0.871   |
# |    learning_rate   | 3.15e-06 |
# |    n_updates       | 4947363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5776     |
# |    fps             | 120      |
# |    time_elapsed    | 41063    |
# |    total_timesteps | 4951464  |
# | train/             |          |
# |    actor_loss      | -472     |
# |    critic_loss     | 1.16     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 0.0354   |
# |    learning_rate   | 2.91e-06 |
# |    n_updates       | 4951363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.04e+03 |
# | time/              |          |
# |    episodes        | 5780     |
# |    fps             | 120      |
# |    time_elapsed    | 41095    |
# |    total_timesteps | 4955464  |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 0.973    |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 0.461    |
# |    learning_rate   | 2.67e-06 |
# |    n_updates       | 4955363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 5.05e+03 |
# | time/              |          |
# |    episodes        | 5784     |
# |    fps             | 120      |
# |    time_elapsed    | 41126    |
# |    total_timesteps | 4959464  |
# | train/             |          |
# |    actor_loss      | -472     |
# |    critic_loss     | 0.99     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 0.623    |
# |    learning_rate   | 2.43e-06 |
# |    n_updates       | 4959363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.09e+03 |
# | time/              |          |
# |    episodes        | 5788     |
# |    fps             | 120      |
# |    time_elapsed    | 41158    |
# |    total_timesteps | 4963464  |
# | train/             |          |
# |    actor_loss      | -475     |
# |    critic_loss     | 0.704    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.248    |
# |    learning_rate   | 2.19e-06 |
# |    n_updates       | 4963363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.1e+03  |
# | time/              |          |
# |    episodes        | 5792     |
# |    fps             | 120      |
# |    time_elapsed    | 41190    |
# |    total_timesteps | 4967464  |
# | train/             |          |
# |    actor_loss      | -477     |
# |    critic_loss     | 0.777    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.0338   |
# |    learning_rate   | 1.95e-06 |
# |    n_updates       | 4967363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.1e+03  |
# | time/              |          |
# |    episodes        | 5796     |
# |    fps             | 120      |
# |    time_elapsed    | 41222    |
# |    total_timesteps | 4971464  |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 0.942    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.18     |
# |    learning_rate   | 1.71e-06 |
# |    n_updates       | 4971363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.1e+03  |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 120      |
# |    time_elapsed    | 41253    |
# |    total_timesteps | 4975464  |
# | train/             |          |
# |    actor_loss      | -470     |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 1.47e-06 |
# |    n_updates       | 4975363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5804     |
# |    fps             | 120      |
# |    time_elapsed    | 41285    |
# |    total_timesteps | 4979464  |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 0.927    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 1.23e-06 |
# |    n_updates       | 4979363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5808     |
# |    fps             | 120      |
# |    time_elapsed    | 41316    |
# |    total_timesteps | 4983464  |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 0.736    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | -0.389   |
# |    learning_rate   | 9.92e-07 |
# |    n_updates       | 4983363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5812     |
# |    fps             | 120      |
# |    time_elapsed    | 41348    |
# |    total_timesteps | 4987464  |
# | train/             |          |
# |    actor_loss      | -477     |
# |    critic_loss     | 0.708    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 7.52e-07 |
# |    n_updates       | 4987363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5816     |
# |    fps             | 120      |
# |    time_elapsed    | 41379    |
# |    total_timesteps | 4991464  |
# | train/             |          |
# |    actor_loss      | -471     |
# |    critic_loss     | 1.58     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 5.12e-07 |
# |    n_updates       | 4991363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5820     |
# |    fps             | 120      |
# |    time_elapsed    | 41410    |
# |    total_timesteps | 4995464  |
# | train/             |          |
# |    actor_loss      | -477     |
# |    critic_loss     | 0.757    |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.391    |
# |    learning_rate   | 2.72e-07 |
# |    n_updates       | 4995363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 5824     |
# |    fps             | 120      |
# |    time_elapsed    | 41442    |
# |    total_timesteps | 4999464  |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.039    |
# |    learning_rate   | 3.22e-08 |
# |    n_updates       | 4999363  |
# ---------------------------------

# %%
results = evaluate_walker_model(
    model_path="Models/action_model_5M_lr.zip",
    num_episodes=100,
    seed=42  
)
# Out:
# Episode 1: Length = 1000, Position = 26.61, Avg Velocity = 3.33, Completed
# Episode 2: Length = 1000, Position = 25.25, Avg Velocity = 3.16, Completed
# Episode 3: Length = 1000, Position = 25.12, Avg Velocity = 3.14, Completed
# Episode 4: Length = 1000, Position = 25.83, Avg Velocity = 3.23, Completed
# Episode 5: Length = 1000, Position = 24.76, Avg Velocity = 3.10, Completed
# Episode 6: Length = 1000, Position = 25.53, Avg Velocity = 3.19, Completed
# Episode 7: Length = 1000, Position = 25.01, Avg Velocity = 3.13, Completed
# Episode 8: Length = 1000, Position = 27.30, Avg Velocity = 3.41, Completed
# Episode 9: Length = 1000, Position = 27.50, Avg Velocity = 3.44, Completed
# Episode 10: Length = 1000, Position = 26.74, Avg Velocity = 3.34, Completed
# Episode 11: Length = 1000, Position = 25.76, Avg Velocity = 3.22, Completed
# Episode 12: Length = 1000, Position = 25.94, Avg Velocity = 3.24, Completed
# Episode 13: Length = 1000, Position = 25.61, Avg Velocity = 3.20, Completed
# Episode 14: Length = 1000, Position = 26.19, Avg Velocity = 3.27, Completed
# Episode 15: Length = 1000, Position = 27.53, Avg Velocity = 3.44, Completed
# Episode 16: Length = 1000, Position = 25.40, Avg Velocity = 3.18, Completed
# Episode 17: Length = 1000, Position = 25.99, Avg Velocity = 3.25, Completed
# Episode 18: Length = 1000, Position = 24.75, Avg Velocity = 3.09, Completed
# Episode 19: Length = 1000, Position = 25.55, Avg Velocity = 3.19, Completed
# Episode 20: Length = 1000, Position = 26.26, Avg Velocity = 3.28, Completed
# Episode 21: Length = 1000, Position = 24.96, Avg Velocity = 3.12, Completed
# Episode 22: Length = 1000, Position = 25.53, Avg Velocity = 3.19, Completed
# Episode 23: Length = 1000, Position = 26.19, Avg Velocity = 3.27, Completed
# Episode 24: Length = 1000, Position = 25.29, Avg Velocity = 3.16, Completed
# Episode 25: Length = 1000, Position = 26.06, Avg Velocity = 3.26, Completed
# Episode 26: Length = 1000, Position = 26.12, Avg Velocity = 3.26, Completed
# Episode 27: Length = 1000, Position = 26.71, Avg Velocity = 3.34, Completed
# Episode 28: Length = 1000, Position = 25.13, Avg Velocity = 3.14, Completed
# Episode 29: Length = 1000, Position = 25.55, Avg Velocity = 3.19, Completed
# Episode 30: Length = 1000, Position = 25.33, Avg Velocity = 3.17, Completed
# Episode 31: Length = 1000, Position = 30.20, Avg Velocity = 3.77, Completed
# Episode 32: Length = 1000, Position = 24.57, Avg Velocity = 3.07, Completed
# Episode 33: Length = 1000, Position = 26.76, Avg Velocity = 3.35, Completed
# Episode 34: Length = 1000, Position = 28.29, Avg Velocity = 3.54, Completed
# Episode 35: Length = 1000, Position = 25.92, Avg Velocity = 3.24, Completed
# Episode 36: Length = 1000, Position = 27.09, Avg Velocity = 3.39, Completed
# Episode 37: Length = 1000, Position = 26.45, Avg Velocity = 3.31, Completed
# Episode 38: Length = 1000, Position = 28.62, Avg Velocity = 3.58, Completed
# Episode 39: Length = 1000, Position = 26.16, Avg Velocity = 3.27, Completed
# Episode 40: Length = 1000, Position = 26.57, Avg Velocity = 3.32, Completed
# Episode 41: Length = 1000, Position = 26.79, Avg Velocity = 3.35, Completed
# Episode 42: Length = 1000, Position = 25.00, Avg Velocity = 3.13, Completed
# Episode 43: Length = 1000, Position = 25.57, Avg Velocity = 3.20, Completed
# Episode 44: Length = 1000, Position = 25.25, Avg Velocity = 3.16, Completed
# Episode 45: Length = 1000, Position = 26.56, Avg Velocity = 3.32, Completed
# Episode 46: Length = 1000, Position = 25.65, Avg Velocity = 3.21, Completed
# Episode 47: Length = 1000, Position = 26.54, Avg Velocity = 3.32, Completed
# Episode 48: Length = 1000, Position = 25.40, Avg Velocity = 3.18, Completed
# Episode 49: Length = 1000, Position = 26.39, Avg Velocity = 3.30, Completed
# Episode 50: Length = 1000, Position = 28.23, Avg Velocity = 3.53, Completed
# Episode 51: Length = 1000, Position = 26.41, Avg Velocity = 3.30, Completed
# Episode 52: Length = 1000, Position = 24.56, Avg Velocity = 3.07, Completed
# Episode 53: Length = 1000, Position = 26.32, Avg Velocity = 3.29, Completed
# Episode 54: Length = 1000, Position = 25.62, Avg Velocity = 3.20, Completed
# Episode 55: Length = 1000, Position = 24.81, Avg Velocity = 3.10, Completed
# Episode 56: Length = 1000, Position = 25.63, Avg Velocity = 3.20, Completed
# Episode 57: Length = 1000, Position = 26.31, Avg Velocity = 3.29, Completed
# Episode 58: Length = 1000, Position = 26.59, Avg Velocity = 3.32, Completed
# Episode 59: Length = 1000, Position = 26.51, Avg Velocity = 3.31, Completed
# Episode 60: Length = 1000, Position = 26.28, Avg Velocity = 3.28, Completed
# Episode 61: Length = 1000, Position = 28.28, Avg Velocity = 3.54, Completed
# Episode 62: Length = 1000, Position = 25.81, Avg Velocity = 3.23, Completed
# Episode 63: Length = 1000, Position = 25.73, Avg Velocity = 3.22, Completed
# Episode 64: Length = 1000, Position = 25.29, Avg Velocity = 3.16, Completed
# Episode 65: Length = 1000, Position = 25.83, Avg Velocity = 3.23, Completed
# Episode 66: Length = 1000, Position = 24.77, Avg Velocity = 3.10, Completed
# Episode 67: Length = 1000, Position = 25.45, Avg Velocity = 3.18, Completed
# Episode 68: Length = 1000, Position = 24.71, Avg Velocity = 3.09, Completed
# Episode 69: Length = 1000, Position = 26.93, Avg Velocity = 3.37, Completed
# Episode 70: Length = 1000, Position = 25.19, Avg Velocity = 3.15, Completed
# Episode 71: Length = 312, Position = 7.43, Avg Velocity = 2.98, Terminated
# Episode 72: Length = 1000, Position = 25.28, Avg Velocity = 3.16, Completed
# Episode 73: Length = 1000, Position = 25.56, Avg Velocity = 3.20, Completed
# Episode 74: Length = 1000, Position = 26.23, Avg Velocity = 3.28, Completed
# Episode 75: Length = 1000, Position = 28.83, Avg Velocity = 3.60, Completed
# Episode 76: Length = 1000, Position = 26.34, Avg Velocity = 3.29, Completed
# Episode 77: Length = 1000, Position = 27.58, Avg Velocity = 3.45, Completed
# Episode 78: Length = 1000, Position = 25.45, Avg Velocity = 3.18, Completed
# Episode 79: Length = 1000, Position = 26.07, Avg Velocity = 3.26, Completed
# Episode 80: Length = 1000, Position = 25.18, Avg Velocity = 3.15, Completed
# Episode 81: Length = 1000, Position = 27.05, Avg Velocity = 3.38, Completed
# Episode 82: Length = 1000, Position = 27.37, Avg Velocity = 3.42, Completed
# Episode 83: Length = 1000, Position = 28.56, Avg Velocity = 3.57, Completed
# Episode 84: Length = 1000, Position = 25.81, Avg Velocity = 3.23, Completed
# Episode 85: Length = 1000, Position = 25.84, Avg Velocity = 3.23, Completed
# Episode 86: Length = 1000, Position = 27.26, Avg Velocity = 3.41, Completed
# Episode 87: Length = 1000, Position = 25.55, Avg Velocity = 3.19, Completed
# Episode 88: Length = 1000, Position = 25.30, Avg Velocity = 3.16, Completed
# Episode 89: Length = 1000, Position = 24.62, Avg Velocity = 3.08, Completed
# Episode 90: Length = 1000, Position = 25.71, Avg Velocity = 3.21, Completed
# Episode 91: Length = 1000, Position = 25.73, Avg Velocity = 3.22, Completed
# Episode 92: Length = 1000, Position = 26.55, Avg Velocity = 3.32, Completed
# Episode 93: Length = 1000, Position = 27.99, Avg Velocity = 3.50, Completed
# Episode 94: Length = 1000, Position = 27.66, Avg Velocity = 3.46, Completed
# Episode 95: Length = 1000, Position = 26.21, Avg Velocity = 3.28, Completed
# Episode 96: Length = 1000, Position = 25.87, Avg Velocity = 3.23, Completed
# Episode 97: Length = 1000, Position = 24.86, Avg Velocity = 3.11, Completed
# Episode 98: Length = 1000, Position = 25.76, Avg Velocity = 3.22, Completed
# Episode 99: Length = 1000, Position = 25.27, Avg Velocity = 3.16, Completed
# Episode 100: Length = 1000, Position = 25.31, Avg Velocity = 3.16, Completed
#
# Evaluation Results:
# Completion Rate: 99.0%
# Average Position: 25.93 ± 2.14
# Average Velocity: 3.26 ± 0.13

# %%
import gymnasium as gym
from stable_baselines3 import SAC

# Load the environment with rendering enabled
env = gym.make('Walker2d-v5', render_mode="human") #With visualization
#env = gym.make('Walker2d-v5') #Without vizualization

# Path to the saved SAC model
model_path = "Models/action_model_5M_lr.zip" #  1 000 000 Timesteps



# Load the trained SAC model
model = SAC.load(model_path)

# Visualize for 30 episodes
for episode in range(30):
    obs, info = env.reset()
    done = False

    while not done:
        # Predict the action using the trained SAC model
        action, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        

        # Check if the episode has ended
        done = terminated or truncated

    # Step through the environment
    
    print(f"Episode {episode}: Terminated={terminated}, Truncated={truncated}, Info={info}")

# Close the environment after visualization
env.close()
# Out:
# Episode 0: Terminated=False, Truncated=True, Info={'x_position': 29.36636194782821, 'z_distance_from_origin': -0.06590854786255695, 'x_velocity': 3.65632408972294, 'reward_forward': 3.65632408972294, 'reward_ctrl': -0.004136053562164307, 'reward_survive': 1.0}
# Episode 1: Terminated=False, Truncated=True, Info={'x_position': 27.837827717554767, 'z_distance_from_origin': -0.16392169877378948, 'x_velocity': 2.7663737559215917, 'reward_forward': 2.7663737559215917, 'reward_ctrl': -0.003016355037689209, 'reward_survive': 1.0}
# Episode 2: Terminated=False, Truncated=True, Info={'x_position': 27.440241657163543, 'z_distance_from_origin': -0.08393274716756927, 'x_velocity': 3.329074783372299, 'reward_forward': 3.329074783372299, 'reward_ctrl': -0.004014641761779785, 'reward_survive': 1.0}
# Episode 3: Terminated=False, Truncated=True, Info={'x_position': 26.007421298855796, 'z_distance_from_origin': -0.0200705238005503, 'x_velocity': 3.0476161356660647, 'reward_forward': 3.0476161356660647, 'reward_ctrl': -0.0020056982040405273, 'reward_survive': 1.0}
# Episode 4: Terminated=False, Truncated=True, Info={'x_position': 27.702839126182358, 'z_distance_from_origin': -0.07623203843189841, 'x_velocity': 3.6449819085793145, 'reward_forward': 3.6449819085793145, 'reward_ctrl': -0.00414509916305542, 'reward_survive': 1.0}
# Episode 5: Terminated=False, Truncated=True, Info={'x_position': 26.77521451630397, 'z_distance_from_origin': -0.004630819641429529, 'x_velocity': 2.9649301189031974, 'reward_forward': 2.9649301189031974, 'reward_ctrl': -0.0036036548614501954, 'reward_survive': 1.0}
# Episode 6: Terminated=False, Truncated=True, Info={'x_position': 28.614497589280074, 'z_distance_from_origin': -0.047781282831896865, 'x_velocity': 3.0272971963278827, 'reward_forward': 3.0272971963278827, 'reward_ctrl': -0.004298742771148682, 'reward_survive': 1.0}
# Episode 7: Terminated=False, Truncated=True, Info={'x_position': 24.69553401159154, 'z_distance_from_origin': 0.03585935148171515, 'x_velocity': 2.8090329457213237, 'reward_forward': 2.8090329457213237, 'reward_ctrl': -0.0024679410457611084, 'reward_survive': 1.0}
# Episode 8: Terminated=False, Truncated=True, Info={'x_position': 26.451830600720836, 'z_distance_from_origin': 0.13120254358117722, 'x_velocity': 3.847079059488223, 'reward_forward': 3.847079059488223, 'reward_ctrl': -0.0018444055318832398, 'reward_survive': 1.0}
# Episode 9: Terminated=False, Truncated=True, Info={'x_position': 29.443363250161145, 'z_distance_from_origin': -0.05528849149315751, 'x_velocity': 3.9841265524844793, 'reward_forward': 3.9841265524844793, 'reward_ctrl': -0.004684211730957032, 'reward_survive': 1.0}
# Episode 10: Terminated=False, Truncated=True, Info={'x_position': 28.023388007208933, 'z_distance_from_origin': 0.001307065554372988, 'x_velocity': 2.487106269826622, 'reward_forward': 2.487106269826622, 'reward_ctrl': -0.0036648006439208985, 'reward_survive': 1.0}
# Episode 11: Terminated=False, Truncated=True, Info={'x_position': 28.544924806538194, 'z_distance_from_origin': 0.0670170018290599, 'x_velocity': 3.72832909107057, 'reward_forward': 3.72832909107057, 'reward_ctrl': -0.0020469956398010253, 'reward_survive': 1.0}
# Episode 12: Terminated=False, Truncated=True, Info={'x_position': 27.502841348035126, 'z_distance_from_origin': 0.037102743637807745, 'x_velocity': 3.590687931516623, 'reward_forward': 3.590687931516623, 'reward_ctrl': -0.002149564504623413, 'reward_survive': 1.0}
# Episode 13: Terminated=False, Truncated=True, Info={'x_position': 26.304795706741473, 'z_distance_from_origin': 0.03979745804348389, 'x_velocity': 3.0378504386527894, 'reward_forward': 3.0378504386527894, 'reward_ctrl': -0.003558355808258057, 'reward_survive': 1.0}
# Episode 14: Terminated=False, Truncated=True, Info={'x_position': 27.580343059065182, 'z_distance_from_origin': 0.06811108155635548, 'x_velocity': 3.6051930407916544, 'reward_forward': 3.6051930407916544, 'reward_ctrl': -0.002073460340499878, 'reward_survive': 1.0}
# Episode 15: Terminated=False, Truncated=True, Info={'x_position': 27.101618627813316, 'z_distance_from_origin': 0.0416607883175506, 'x_velocity': 2.539845573599653, 'reward_forward': 2.539845573599653, 'reward_ctrl': -0.0030255000591278077, 'reward_survive': 1.0}
# Episode 16: Terminated=False, Truncated=True, Info={'x_position': 25.70751049142842, 'z_distance_from_origin': 0.033695598806884774, 'x_velocity': 2.3395261142247215, 'reward_forward': 2.3395261142247215, 'reward_ctrl': -0.0033182294368743898, 'reward_survive': 1.0}
# Episode 17: Terminated=False, Truncated=True, Info={'x_position': 26.080894455538893, 'z_distance_from_origin': -0.028230113279733127, 'x_velocity': 2.125583382901919, 'reward_forward': 2.125583382901919, 'reward_ctrl': -0.004056282997131348, 'reward_survive': 1.0}
# Episode 18: Terminated=False, Truncated=True, Info={'x_position': 29.29015672235131, 'z_distance_from_origin': 0.011015279508191256, 'x_velocity': 3.1436591840470207, 'reward_forward': 3.1436591840470207, 'reward_ctrl': -0.0028319170475006104, 'reward_survive': 1.0}
# Episode 19: Terminated=False, Truncated=True, Info={'x_position': 27.706294998072085, 'z_distance_from_origin': -0.08221438450304586, 'x_velocity': 4.116407871785022, 'reward_forward': 4.116407871785022, 'reward_ctrl': -0.003406788110733032, 'reward_survive': 1.0}
# Episode 20: Terminated=False, Truncated=True, Info={'x_position': 26.118771083237036, 'z_distance_from_origin': 0.034675738725673755, 'x_velocity': 3.0375384447549614, 'reward_forward': 3.0375384447549614, 'reward_ctrl': -0.002798961877822876, 'reward_survive': 1.0}
# Episode 21: Terminated=False, Truncated=True, Info={'x_position': 25.28069651555909, 'z_distance_from_origin': 0.03596849278136971, 'x_velocity': 2.9863869085087202, 'reward_forward': 2.9863869085087202, 'reward_ctrl': -0.0029009971618652345, 'reward_survive': 1.0}
# Episode 22: Terminated=False, Truncated=True, Info={'x_position': 25.724696892692574, 'z_distance_from_origin': -0.05363624822608726, 'x_velocity': 3.646216626009391, 'reward_forward': 3.646216626009391, 'reward_ctrl': -0.00231240439414978, 'reward_survive': 1.0}
# Episode 23: Terminated=False, Truncated=True, Info={'x_position': 27.147384778968423, 'z_distance_from_origin': -0.010489176155726865, 'x_velocity': 4.033765111482346, 'reward_forward': 4.033765111482346, 'reward_ctrl': -0.0019018008708953857, 'reward_survive': 1.0}
# Episode 24: Terminated=False, Truncated=True, Info={'x_position': 28.045736599627585, 'z_distance_from_origin': -0.03360826535887673, 'x_velocity': 3.492829306484868, 'reward_forward': 3.492829306484868, 'reward_ctrl': -0.0037211408615112304, 'reward_survive': 1.0}
# Episode 25: Terminated=False, Truncated=True, Info={'x_position': 25.383910207997406, 'z_distance_from_origin': 0.04625601515287259, 'x_velocity': 3.2752101820339163, 'reward_forward': 3.2752101820339163, 'reward_ctrl': -0.0015679446458816528, 'reward_survive': 1.0}
# Episode 26: Terminated=False, Truncated=True, Info={'x_position': 26.20627466341618, 'z_distance_from_origin': -0.11303528852761913, 'x_velocity': 3.323255630260036, 'reward_forward': 3.323255630260036, 'reward_ctrl': -0.0038546710014343262, 'reward_survive': 1.0}
# Episode 27: Terminated=False, Truncated=True, Info={'x_position': 26.85005162466526, 'z_distance_from_origin': 0.08204950952726042, 'x_velocity': 3.8993884590343697, 'reward_forward': 3.8993884590343697, 'reward_ctrl': -0.0014960895776748658, 'reward_survive': 1.0}
# Episode 28: Terminated=False, Truncated=True, Info={'x_position': 26.355949444516725, 'z_distance_from_origin': -0.030323374459428676, 'x_velocity': 2.1563617119708667, 'reward_forward': 2.1563617119708667, 'reward_ctrl': -0.004545660972595215, 'reward_survive': 1.0}
# Episode 29: Terminated=False, Truncated=True, Info={'x_position': 25.746590216001053, 'z_distance_from_origin': 0.04465900781813725, 'x_velocity': 3.4425151837318424, 'reward_forward': 3.4425151837318424, 'reward_ctrl': -0.00213544225692749, 'reward_survive': 1.0}
